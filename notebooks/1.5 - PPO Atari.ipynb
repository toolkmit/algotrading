# %%
import sys
from baselines import logger, bench
from baselines.common import set_global_seeds
from baselines.common.cmd_util import make_atari_env, atari_arg_parser
from baselines.common.atari_wrappers import wrap_deepmind, make_atari
from baselines.common.vec_env.vec_frame_stack import VecFrameStack
from baselines.common.vec_env.dummy_vec_env import DummyVecEnv
from baselines.ppo2 import ppo2
from baselines.ppo2.policies import CnnPolicy, LstmPolicy, LnLstmPolicy, MlpPolicy
import multiprocessing
import tensorflow as tf
# Out:
# /home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def train(env_id, num_timesteps, seed, policy):

    ncpu = multiprocessing.cpu_count()
    if sys.platform == 'darwin': ncpu //= 2
    config = tf.ConfigProto(allow_soft_placement=True,
                            intra_op_parallelism_threads=ncpu,
                            inter_op_parallelism_threads=ncpu)
    config.gpu_options.allow_growth = True #pylint: disable=E1101
    tf.Session(config=config).__enter__()
    
    def make_env():
        env = make_atari(env_id)
        env = bench.Monitor(env, logger.get_dir(), allow_early_resets=True)
        return wrap_deepmind(env)
    
    set_global_seeds(seed)
    
    env = DummyVecEnv([make_env])

    #env = VecFrameStack(make_atari_env(env_id, 8, seed), 4)
    policy = {'cnn' : CnnPolicy, 'lstm' : LstmPolicy, 'lnlstm' : LnLstmPolicy, 'mlp': MlpPolicy}[policy]
    ppo2.learn(policy=policy, env=env, nsteps=128, nminibatches=4,
        lam=0.95, gamma=0.99, noptepochs=4, log_interval=1,
        ent_coef=.01,
        lr=lambda f : f * 2.5e-4,
        cliprange=lambda f : f * 0.1,
        total_timesteps=int(num_timesteps * 1.1))

# %%
logger.configure()

train('BreakoutNoFrameskip-v4', num_timesteps=1e6, seed=0, policy='cnn')
# Out:
# Logging to /tmp/openai-2018-05-29-14-05-05-497996
# WARNING:tensorflow:From /home/ubuntu/repos/baselines/baselines/common/distributions.py:148: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# WARNING:tensorflow:From /home/ubuntu/repos/baselines/baselines/common/distributions.py:159: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/ubuntu/repos/baselines/baselines/common/distributions.py:161: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# --------------------------------------
# | approxkl           | 0.003608401   |
# | clipfrac           | 0.22851562    |
# | eplenmean          | nan           |
# | eprewmean          | nan           |
# | explained_variance | 0.0315        |
# | fps                | 83            |
# | nupdates           | 1             |
# | policy_entropy     | 1.3826978     |
# | policy_loss        | -0.0109578855 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 1.54          |
# | total_timesteps    | 128           |
# | value_loss         | 0.052479424   |
# --------------------------------------
# Saving to /tmp/openai-2018-05-29-14-05-05-497996/checkpoints/00001
# --------------------------------------
# | approxkl           | 0.0014572896  |
# | clipfrac           | 0.13085938    |
# | eplenmean          | 173           |
# | eprewmean          | 1             |
# | explained_variance | 0.0369        |
# | fps                | 212           |
# | nupdates           | 2             |
# | policy_entropy     | 1.3768544     |
# | policy_loss        | -0.0038329393 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 2.16          |
# | total_timesteps    | 256           |
# | value_loss         | 0.033172652   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0038540394 |
# | clipfrac           | 0.2578125    |
# | eplenmean          | 198          |
# | eprewmean          | 1.5          |
# | explained_variance | -0.0131      |
# | fps                | 211          |
# | nupdates           | 3            |
# | policy_entropy     | 1.3514874    |
# | policy_loss        | -0.004465679 |
# | serial_timesteps   | 384          |
# | time_elapsed       | 2.77         |
# | total_timesteps    | 384          |
# | value_loss         | 0.024932956  |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.002242264 |
# | clipfrac           | 0.109375    |
# | eplenmean          | 198         |
# | eprewmean          | 1.5         |
# | explained_variance | 0.0269      |
# | fps                | 220         |
# | nupdates           | 4           |
# | policy_entropy     | 1.3425525   |
# | policy_loss        | -0.0054568  |
# | serial_timesteps   | 512         |
# | time_elapsed       | 3.35        |
# | total_timesteps    | 512         |
# | value_loss         | 0.034075998 |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.003006136  |
# | clipfrac           | 0.265625     |
# | eplenmean          | 205          |
# | eprewmean          | 1.67         |
# | explained_variance | -0.0345      |
# | fps                | 211          |
# | nupdates           | 5            |
# | policy_entropy     | 1.3449141    |
# | policy_loss        | -0.006536348 |
# | serial_timesteps   | 640          |
# | time_elapsed       | 3.96         |
# | total_timesteps    | 640          |
# | value_loss         | 0.027754236  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0016217538 |
# | clipfrac           | 0.095703125  |
# | eplenmean          | 186          |
# | eprewmean          | 1.25         |
# | explained_variance | 0.0493       |
# | fps                | 216          |
# | nupdates           | 6            |
# | policy_entropy     | 1.3165433    |
# | policy_loss        | -0.004218353 |
# | serial_timesteps   | 768          |
# | time_elapsed       | 4.55         |
# | total_timesteps    | 768          |
# | value_loss         | 0.0036584898 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00220745    |
# | clipfrac           | 0.109375      |
# | eplenmean          | 174           |
# | eprewmean          | 1             |
# | explained_variance | -1.49         |
# | fps                | 215           |
# | nupdates           | 7             |
# | policy_entropy     | 1.3448448     |
# | policy_loss        | -0.0016994572 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 5.15          |
# | total_timesteps    | 896           |
# | value_loss         | 0.00024458062 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0016447965  |
# | clipfrac           | 0.06640625    |
# | eplenmean          | 166           |
# | eprewmean          | 0.833         |
# | explained_variance | -0.0483       |
# | fps                | 219           |
# | nupdates           | 8             |
# | policy_entropy     | 1.3289376     |
# | policy_loss        | -0.0057207327 |
# | serial_timesteps   | 1024          |
# | time_elapsed       | 5.73          |
# | total_timesteps    | 1024          |
# | value_loss         | 0.030234842   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00071852305 |
# | clipfrac           | 0.029296875   |
# | eplenmean          | 167           |
# | eprewmean          | 0.857         |
# | explained_variance | 0.192         |
# | fps                | 214           |
# | nupdates           | 9             |
# | policy_entropy     | 1.3200712     |
# | policy_loss        | 0.0006523101  |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 6.33          |
# | total_timesteps    | 1152          |
# | value_loss         | 0.0011440585  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0008961337  |
# | clipfrac           | 0.03515625    |
# | eplenmean          | 163           |
# | eprewmean          | 0.75          |
# | explained_variance | -0.0119       |
# | fps                | 218           |
# | nupdates           | 10            |
# | policy_entropy     | 1.2969077     |
# | policy_loss        | -0.0031424137 |
# | serial_timesteps   | 1280          |
# | time_elapsed       | 6.92          |
# | total_timesteps    | 1280          |
# | value_loss         | 0.032711845   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0011632378 |
# | clipfrac           | 0.01953125   |
# | eplenmean          | 167          |
# | eprewmean          | 0.889        |
# | explained_variance | 0.0726       |
# | fps                | 212          |
# | nupdates           | 11           |
# | policy_entropy     | 1.309906     |
# | policy_loss        | 0.0005367729 |
# | serial_timesteps   | 1408         |
# | time_elapsed       | 7.52         |
# | total_timesteps    | 1408         |
# | value_loss         | 0.026657602  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0012508384  |
# | clipfrac           | 0.064453125   |
# | eplenmean          | 163           |
# | eprewmean          | 0.8           |
# | explained_variance | 0.0013        |
# | fps                | 208           |
# | nupdates           | 12            |
# | policy_entropy     | 1.333309      |
# | policy_loss        | -0.0060645947 |
# | serial_timesteps   | 1536          |
# | time_elapsed       | 8.13          |
# | total_timesteps    | 1536          |
# | value_loss         | 0.001759201   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00035171915  |
# | clipfrac           | 0.0            |
# | eplenmean          | 160            |
# | eprewmean          | 0.727          |
# | explained_variance | 0.0155         |
# | fps                | 205            |
# | nupdates           | 13             |
# | policy_entropy     | 1.3287711      |
# | policy_loss        | -0.00041101174 |
# | serial_timesteps   | 1664           |
# | time_elapsed       | 8.76           |
# | total_timesteps    | 1664           |
# | value_loss         | 0.031788915    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0048580747  |
# | clipfrac           | 0.28320312    |
# | eplenmean          | 161           |
# | eprewmean          | 0.75          |
# | explained_variance | -0.228        |
# | fps                | 204           |
# | nupdates           | 14            |
# | policy_entropy     | 1.2966607     |
# | policy_loss        | -0.0044763307 |
# | serial_timesteps   | 1792          |
# | time_elapsed       | 9.39          |
# | total_timesteps    | 1792          |
# | value_loss         | 0.0008044718  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005203548  |
# | clipfrac           | 0.0234375     |
# | eplenmean          | 161           |
# | eprewmean          | 0.75          |
# | explained_variance | 0.123         |
# | fps                | 216           |
# | nupdates           | 15            |
# | policy_entropy     | 1.3094387     |
# | policy_loss        | 0.00069902395 |
# | serial_timesteps   | 1920          |
# | time_elapsed       | 9.98          |
# | total_timesteps    | 1920          |
# | value_loss         | 0.058084954   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0007776865  |
# | clipfrac           | 0.041015625   |
# | eplenmean          | 171           |
# | eprewmean          | 1             |
# | explained_variance | -0.00101      |
# | fps                | 208           |
# | nupdates           | 16            |
# | policy_entropy     | 1.3187196     |
# | policy_loss        | 0.00014257338 |
# | serial_timesteps   | 2048          |
# | time_elapsed       | 10.6          |
# | total_timesteps    | 2048          |
# | value_loss         | 0.056541078   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0007982135  |
# | clipfrac           | 0.0390625     |
# | eplenmean          | 171           |
# | eprewmean          | 1             |
# | explained_variance | 0.205         |
# | fps                | 228           |
# | nupdates           | 17            |
# | policy_entropy     | 1.3191453     |
# | policy_loss        | -0.0016751986 |
# | serial_timesteps   | 2176          |
# | time_elapsed       | 11.2          |
# | total_timesteps    | 2176          |
# | value_loss         | 0.04821456    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0014560912 |
# | clipfrac           | 0.09765625   |
# | eplenmean          | 171          |
# | eprewmean          | 1            |
# | explained_variance | -0.0144      |
# | fps                | 216          |
# | nupdates           | 18           |
# | policy_entropy     | 1.3245751    |
# | policy_loss        | -0.007517661 |
# | serial_timesteps   | 2304         |
# | time_elapsed       | 11.7         |
# | total_timesteps    | 2304         |
# | value_loss         | 0.050996162  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.003476592  |
# | clipfrac           | 0.28515625   |
# | eplenmean          | 186          |
# | eprewmean          | 1.36         |
# | explained_variance | 0.0387       |
# | fps                | 216          |
# | nupdates           | 19           |
# | policy_entropy     | 1.3022963    |
# | policy_loss        | -0.005224663 |
# | serial_timesteps   | 2432         |
# | time_elapsed       | 12.3         |
# | total_timesteps    | 2432         |
# | value_loss         | 0.058282614  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0010447936 |
# | clipfrac           | 0.076171875  |
# | eplenmean          | 186          |
# | eprewmean          | 1.36         |
# | explained_variance | 0.11         |
# | fps                | 214          |
# | nupdates           | 20           |
# | policy_entropy     | 1.321376     |
# | policy_loss        | -0.003293739 |
# | serial_timesteps   | 2560         |
# | time_elapsed       | 12.9         |
# | total_timesteps    | 2560         |
# | value_loss         | 0.070134945  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0022109023  |
# | clipfrac           | 0.10546875    |
# | eplenmean          | 186           |
# | eprewmean          | 1.36          |
# | explained_variance | 0.0667        |
# | fps                | 229           |
# | nupdates           | 21            |
# | policy_entropy     | 1.2787004     |
# | policy_loss        | -0.0007290235 |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 13.5          |
# | total_timesteps    | 2688          |
# | value_loss         | 0.052605532   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0014072568  |
# | clipfrac           | 0.02734375    |
# | eplenmean          | 197           |
# | eprewmean          | 1.6           |
# | explained_variance | -0.405        |
# | fps                | 211           |
# | nupdates           | 22            |
# | policy_entropy     | 1.3175334     |
# | policy_loss        | -0.0011430782 |
# | serial_timesteps   | 2816          |
# | time_elapsed       | 14.1          |
# | total_timesteps    | 2816          |
# | value_loss         | 0.06291733    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0022197538  |
# | clipfrac           | 0.119140625   |
# | eplenmean          | 196           |
# | eprewmean          | 1.56          |
# | explained_variance | 0.0438        |
# | fps                | 220           |
# | nupdates           | 23            |
# | policy_entropy     | 1.2879982     |
# | policy_loss        | -0.0034916745 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 14.7          |
# | total_timesteps    | 2944          |
# | value_loss         | 0.07212314    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0019963328  |
# | clipfrac           | 0.14453125    |
# | eplenmean          | 192           |
# | eprewmean          | 1.47          |
# | explained_variance | 0.0838        |
# | fps                | 219           |
# | nupdates           | 24            |
# | policy_entropy     | 1.2994004     |
# | policy_loss        | -0.0013194417 |
# | serial_timesteps   | 3072          |
# | time_elapsed       | 15.3          |
# | total_timesteps    | 3072          |
# | value_loss         | 0.06230591    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0018935506  |
# | clipfrac           | 0.103515625   |
# | eplenmean          | 192           |
# | eprewmean          | 1.47          |
# | explained_variance | 0.172         |
# | fps                | 220           |
# | nupdates           | 25            |
# | policy_entropy     | 1.2675637     |
# | policy_loss        | -0.0059530158 |
# | serial_timesteps   | 3200          |
# | time_elapsed       | 15.8          |
# | total_timesteps    | 3200          |
# | value_loss         | 0.044340882   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.001036125   |
# | clipfrac           | 0.0546875     |
# | eplenmean          | 192           |
# | eprewmean          | 1.47          |
# | explained_variance | 0.152         |
# | fps                | 223           |
# | nupdates           | 26            |
# | policy_entropy     | 1.2524588     |
# | policy_loss        | -0.0017823516 |
# | serial_timesteps   | 3328          |
# | time_elapsed       | 16.4          |
# | total_timesteps    | 3328          |
# | value_loss         | 0.045776375   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0024716053  |
# | clipfrac           | 0.16210938    |
# | eplenmean          | 204           |
# | eprewmean          | 1.89          |
# | explained_variance | 0.37          |
# | fps                | 217           |
# | nupdates           | 27            |
# | policy_entropy     | 1.2943681     |
# | policy_loss        | -0.0029396592 |
# | serial_timesteps   | 3456          |
# | time_elapsed       | 17            |
# | total_timesteps    | 3456          |
# | value_loss         | 0.04687352    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0013937871  |
# | clipfrac           | 0.078125      |
# | eplenmean          | 204           |
# | eprewmean          | 1.89          |
# | explained_variance | 0.154         |
# | fps                | 227           |
# | nupdates           | 28            |
# | policy_entropy     | 1.291037      |
# | policy_loss        | -0.0046192077 |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 17.6          |
# | total_timesteps    | 3584          |
# | value_loss         | 0.050503097   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0029675744 |
# | clipfrac           | 0.22070312   |
# | eplenmean          | 204          |
# | eprewmean          | 1.89         |
# | explained_variance | 0.37         |
# | fps                | 228          |
# | nupdates           | 29           |
# | policy_entropy     | 1.2533236    |
# | policy_loss        | -0.007771855 |
# | serial_timesteps   | 3712         |
# | time_elapsed       | 18.1         |
# | total_timesteps    | 3712         |
# | value_loss         | 0.036418125  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00089759147 |
# | clipfrac           | 0.041015625   |
# | eplenmean          | 204           |
# | eprewmean          | 1.89          |
# | explained_variance | 0.356         |
# | fps                | 226           |
# | nupdates           | 30            |
# | policy_entropy     | 1.2779698     |
# | policy_loss        | -0.003119274  |
# | serial_timesteps   | 3840          |
# | time_elapsed       | 18.7          |
# | total_timesteps    | 3840          |
# | value_loss         | 0.043822296   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0026793545  |
# | clipfrac           | 0.2578125     |
# | eplenmean          | 219           |
# | eprewmean          | 2.37          |
# | explained_variance | -1.44         |
# | fps                | 215           |
# | nupdates           | 31            |
# | policy_entropy     | 1.2883002     |
# | policy_loss        | -0.0022893213 |
# | serial_timesteps   | 3968          |
# | time_elapsed       | 19.3          |
# | total_timesteps    | 3968          |
# | value_loss         | 0.094443075   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.005276754  |
# | clipfrac           | 0.27539062   |
# | eplenmean          | 215          |
# | eprewmean          | 2.25         |
# | explained_variance | 0.0733       |
# | fps                | 219          |
# | nupdates           | 32           |
# | policy_entropy     | 1.3066895    |
# | policy_loss        | -0.009894284 |
# | serial_timesteps   | 4096         |
# | time_elapsed       | 19.9         |
# | total_timesteps    | 4096         |
# | value_loss         | 0.07564815   |
# -------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-17931bc8f9ad> in <module>()
#       1 logger.configure()
#       2
# ----> 3 train('BreakoutNoFrameskip-v4', num_timesteps=1e6, seed=0, policy='cnn')
#
# <ipython-input-2-dde922188bb8> in train(env_id, num_timesteps, seed, policy)
#      25         lr=lambda f : f * 2.5e-4,
#      26         cliprange=lambda f : f * 0.1,
# ---> 27         total_timesteps=int(num_timesteps * 1.1))
#
# ~/repos/baselines/baselines/ppo2/ppo2.py in learn(policy, env, nsteps, total_timesteps, ent_coef, lr, vf_coef, max_grad_norm, gamma, lam, log_interval, nminibatches, noptepochs, cliprange, save_interval, load_path)
#     200                     mbinds = inds[start:end]
#     201                     slices = (arr[mbinds] for arr in (obs, returns, masks, actions, values, neglogpacs))
# --> 202                     mblossvals.append(model.train(lrnow, cliprangenow, *slices))
#     203         else: # recurrent version
#     204             assert nenvs % nminibatches == 0
#
# ~/repos/baselines/baselines/ppo2/ppo2.py in train(lr, cliprange, obs, returns, masks, actions, values, neglogpacs, states)
#      60             return sess.run(
#      61                 [pg_loss, vf_loss, entropy, approxkl, clipfrac, _train],
# ---> 62                 td_map
#      63             )[:-1]
#      64         self.loss_names = ['policy_loss', 'value_loss', 'policy_entropy', 'approxkl', 'clipfrac']
#
# ~/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# ~/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
load_path = '../data/processed/atari-00950'
# !head $load_path
# Out:
# �]q(cjoblib.numpy_pickle
# NumpyArrayWrapper
# subclassqcnumpy
# ndarray
# XCq	Xdtypeq
# cnumpy
# dtype
# Rq(KX<qNNNJ����J����KtqbX
# �;�:;=���>��(��p���<�
# ?�-�(��޴=��f���<4�^=���=��J<8p]��,ܽ��ؽ�=zM���ܽ��H>0�g�uQ6��&�m�ʽ7N����f=��j��bi���;� H�=T��=�.=t�Ƚ�����)�$�f<@�
