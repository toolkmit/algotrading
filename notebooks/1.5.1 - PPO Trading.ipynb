# %%
import sys
import os
from baselines import logger, bench
from baselines.common import set_global_seeds
from baselines.common.cmd_util import make_atari_env, atari_arg_parser
from baselines.common.atari_wrappers import wrap_deepmind, make_atari
from baselines.common.vec_env.vec_frame_stack import VecFrameStack
from baselines.common.vec_env.dummy_vec_env import DummyVecEnv
from baselines.common.vec_env.subproc_vec_env import SubprocVecEnv
from baselines.common.vec_env.vec_normalize import VecNormalize, VecNormalizeTest
from baselines.ppo2 import ppo2
#from baselines.ppo2.policies import CnnPolicy, LstmPolicy, LnLstmPolicy, MlpPolicy
import multiprocessing
import tensorflow as tf
import pandas as pd
import numpy as np
import gym

from src.common.environments import ESTradingEnv

import matplotlib as mpl
# %matplotlib
# Out:
# /home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using matplotlib backend: Qt5Agg
# /home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: The finance module has been deprecated in mpl 2.0 and will be removed in mpl 2.2. Please use the module mpl_finance instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
#Register trading environment with OpenAI Gym
from gym.envs.registration import register
register(id='tradingenv-v0',
         entry_point='src.common.environments:ESTradingEnv_v2',)

# %%
from baselines.a2c.utils import fc, conv_to_fc, lstm, batch_to_seq, seq_to_batch
from baselines.common.distributions import make_pdtype
from baselines.common.input import observation_input

def ortho_init(scale=1.0):
    def _ortho_init(shape, dtype, partition_info=None):
        #lasagne ortho init for tf
        shape = tuple(shape)
        if len(shape) == 2:
            flat_shape = shape
        elif len(shape) > 2: # assumes NHWC
            flat_shape = (np.prod(shape[:-1]), shape[-1])
        else:
            raise NotImplementedError
        a = np.random.normal(0.0, 1.0, flat_shape)
        u, _, v = np.linalg.svd(a, full_matrices=False)
        q = u if u.shape == flat_shape else v # pick the one with the correct shape
        q = q.reshape(shape)
        return (scale * q[:shape[0], :shape[1]]).astype(np.float32)
    return _ortho_init

def conv(x, scope, *, nf, rf, stride, pad='VALID', init_scale=1.0, one_dim_bias=False):    
    channel_ax = 2
    strides = [1, stride, 1]
    bshape = [1, 1, nf]
    
    nin = x.get_shape()[channel_ax].value
    wshape = [rf, nin, nf]
    with tf.variable_scope(scope):
        w = tf.get_variable("w", wshape, initializer=ortho_init(init_scale))
        b = tf.get_variable("b", bshape, initializer=tf.constant_initializer(0.0))
        return b + tf.nn.conv1d(x, w, stride=stride, padding=pad)


def cnn(X, is_training, **conv_kwargs):
    activ = tf.nn.relu
    h = activ(conv(X, 'c1', nf=16, rf=4, stride=1, init_scale=np.sqrt(2),
                   **conv_kwargs))
    h = tf.layers.dropout(h, rate=0.5, training=is_training)
    h2 = activ(conv(h, 'c2', nf=8, rf=4, stride=1, init_scale=np.sqrt(2), **conv_kwargs))
    h2 = tf.layers.dropout(h2, rate=0.5, training=is_training)
    h3 = conv_to_fc(h2)
    return activ(fc(h3, 'fc1', nh=32, init_scale=np.sqrt(2)))


class CnnPolicy(object):

    def __init__(self, sess, ob_space, ac_space, nbatch, nsteps, reuse=False, **conv_kwargs): #pylint: disable=W0613
        if nsteps == 1:
            self._is_training = False
        else:
            self._is_training = True
            
        self.pdtype = make_pdtype(ac_space)
        X, processed_x = observation_input(ob_space, nbatch)
        with tf.variable_scope("model", reuse=reuse):
            h = cnn(processed_x, self._is_training, **conv_kwargs)
            #activ = tf.nn.relu
            #print(processed_x.get_shape())
            #h = activ(fc(processed_x, 'fc1', nh=512, init_scale=np.sqrt(2)))
            vf = fc(h, 'v', 1)[:,0]
            self.pd, self.pi = self.pdtype.pdfromlatent(h, init_scale=0.01)

        a0 = self.pd.sample()
        neglogp0 = self.pd.neglogp(a0)
        self.initial_state = None

        def step(ob, *_args, **_kwargs):
            a, v, neglogp = sess.run([a0, vf, neglogp0], {X:ob})
            return a, v, self.initial_state, neglogp

        def value(ob, *_args, **_kwargs):
            return sess.run(vf, {X:ob})

        self.X = X
        self.vf = vf
        self.step = step
        self.value = value
        
class LstmPolicy(object):

    def __init__(self, sess, ob_space, ac_space, nbatch, nsteps, nlstm=256, reuse=False):
        if nsteps == 1:
            self._is_training = False
        else:
            self._is_training = True
            
        nenv = nbatch // nsteps
        self.pdtype = make_pdtype(ac_space)
        X, processed_x = observation_input(ob_space, nbatch)

        M = tf.placeholder(tf.float32, [nbatch]) #mask (done t-1)
        S = tf.placeholder(tf.float32, [nenv, nlstm*2]) #states
        with tf.variable_scope("model", reuse=reuse):
            h = cnn(processed_x, self._is_training)
            xs = batch_to_seq(h, nenv, nsteps)
            ms = batch_to_seq(M, nenv, nsteps)
            h5, snew = lstm(xs, ms, S, 'lstm1', nh=nlstm)
            h5 = tf.layers.dropout(h5, rate=0.5, training=self._is_training)
            h5 = seq_to_batch(h5)
            vf = fc(h5, 'v', 1)
            self.pd, self.pi = self.pdtype.pdfromlatent(h5)

        v0 = vf[:, 0]
        a0 = self.pd.sample()
        neglogp0 = self.pd.neglogp(a0)
        self.initial_state = np.zeros((nenv, nlstm*2), dtype=np.float32)

        def step(ob, state, mask):
            return sess.run([a0, v0, snew, neglogp0], {X:ob, S:state, M:mask})

        def value(ob, state, mask):
            return sess.run(v0, {X:ob, S:state, M:mask})

        self.X = X
        self.M = M
        self.S = S
        self.vf = vf
        self.step = step
        self.value = value

# %%
def train(env_id, num_timesteps, seed, policy):

    ncpu = multiprocessing.cpu_count()
    if sys.platform == 'darwin': ncpu //= 2
    config = tf.ConfigProto(allow_soft_placement=True,
                            intra_op_parallelism_threads=ncpu,
                            inter_op_parallelism_threads=ncpu)
    config.gpu_options.allow_growth = True #pylint: disable=E1101
    tf.Session(config=config).__enter__()
    
    def make_env(rank):
        def _thunk():
            env = gym.make(env_id)
            env.seed(seed + rank)
            env = bench.Monitor(env, logger.get_dir() and os.path.join(logger.get_dir(), str(rank)))
            return env
        return _thunk
    

    #env = DummyVecEnv([make_env])
    env = SubprocVecEnv([make_env(i) for i in range(32)])
    env = VecNormalize(env, ob=True)
    set_global_seeds(seed)

    policy = LstmPolicy
    ppo2.learn(policy=policy, env=env, nsteps=128, nminibatches=4,
        lam=0.95, gamma=0.99, noptepochs=25, log_interval=1,
        ent_coef=.01,
        lr=lambda f: f * 2.5e-4,
        cliprange=0.1,
        total_timesteps=int(num_timesteps * 1.1))

# %%
logger.configure()

train('tradingenv-v0', num_timesteps=1e7, seed=0, policy='cnn')
# Out:
# Logging to /tmp/openai-2018-05-30-18-51-01-525742
# WARNING:tensorflow:From /home/ubuntu/repos/baselines/baselines/common/distributions.py:148: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# WARNING:tensorflow:From /home/ubuntu/repos/baselines/baselines/common/distributions.py:159: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/ubuntu/repos/baselines/baselines/common/distributions.py:161: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# --------------------------------------
# | approxkl           | 0.000938044   |
# | clipfrac           | 0.021708984   |
# | eplenmean          | 96.5          |
# | eprewmean          | -523          |
# | explained_variance | -0.297        |
# | fps                | 638           |
# | nupdates           | 1             |
# | policy_entropy     | 1.0976362     |
# | policy_loss        | -0.0011973628 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 6.41          |
# | total_timesteps    | 4096          |
# | value_loss         | 0.6793031     |
# --------------------------------------
# Saving to /tmp/openai-2018-05-30-18-51-01-525742/checkpoints/00001
# --------------------------------------
# | approxkl           | 0.0010016048  |
# | clipfrac           | 0.027216798   |
# | eplenmean          | 136           |
# | eprewmean          | -519          |
# | explained_variance | -0.0283       |
# | fps                | 760           |
# | nupdates           | 2             |
# | policy_entropy     | 1.0970252     |
# | policy_loss        | -0.0015181303 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 11.8          |
# | total_timesteps    | 8192          |
# | value_loss         | 0.10791373    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0011440626  |
# | clipfrac           | 0.03453125    |
# | eplenmean          | 157           |
# | eprewmean          | -519          |
# | explained_variance | 0.0243        |
# | fps                | 782           |
# | nupdates           | 3             |
# | policy_entropy     | 1.0954875     |
# | policy_loss        | -0.0013680704 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 17            |
# | total_timesteps    | 12288         |
# | value_loss         | 0.07764729    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0011832734 |
# | clipfrac           | 0.032802735  |
# | eplenmean          | 167          |
# | eprewmean          | -520         |
# | explained_variance | -0.00282     |
# | fps                | 781          |
# | nupdates           | 4            |
# | policy_entropy     | 1.0929594    |
# | policy_loss        | -0.001626886 |
# | serial_timesteps   | 512          |
# | time_elapsed       | 22.3         |
# | total_timesteps    | 16384        |
# | value_loss         | 0.070564866  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0014780496  |
# | clipfrac           | 0.049384765   |
# | eplenmean          | 171           |
# | eprewmean          | -522          |
# | explained_variance | 0.0298        |
# | fps                | 777           |
# | nupdates           | 5             |
# | policy_entropy     | 1.0896788     |
# | policy_loss        | -0.0016572316 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 27.6          |
# | total_timesteps    | 20480         |
# | value_loss         | 0.066586345   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0015196282  |
# | clipfrac           | 0.050048828   |
# | eplenmean          | 182           |
# | eprewmean          | -522          |
# | explained_variance | 0.0141        |
# | fps                | 780           |
# | nupdates           | 6             |
# | policy_entropy     | 1.0864801     |
# | policy_loss        | -0.0016705111 |
# | serial_timesteps   | 768           |
# | time_elapsed       | 32.8          |
# | total_timesteps    | 24576         |
# | value_loss         | 0.06399445    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0016425551  |
# | clipfrac           | 0.058564454   |
# | eplenmean          | 193           |
# | eprewmean          | -525          |
# | explained_variance | -0.0269       |
# | fps                | 771           |
# | nupdates           | 7             |
# | policy_entropy     | 1.0825464     |
# | policy_loss        | -0.0019657714 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 38.1          |
# | total_timesteps    | 28672         |
# | value_loss         | 0.06129856    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0010372512  |
# | clipfrac           | 0.031845704   |
# | eplenmean          | 203           |
# | eprewmean          | -526          |
# | explained_variance | 0.00407       |
# | fps                | 790           |
# | nupdates           | 8             |
# | policy_entropy     | 1.082471      |
# | policy_loss        | -0.0005971006 |
# | serial_timesteps   | 1024          |
# | time_elapsed       | 43.3          |
# | total_timesteps    | 32768         |
# | value_loss         | 0.07005843    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00097283215  |
# | clipfrac           | 0.027724609    |
# | eplenmean          | 207            |
# | eprewmean          | -526           |
# | explained_variance | 0.0307         |
# | fps                | 783            |
# | nupdates           | 9              |
# | policy_entropy     | 1.0815884      |
# | policy_loss        | -0.00018837996 |
# | serial_timesteps   | 1152           |
# | time_elapsed       | 48.5           |
# | total_timesteps    | 36864          |
# | value_loss         | 0.071912244    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.0014855565   |
# | clipfrac           | 0.05272461     |
# | eplenmean          | 202            |
# | eprewmean          | -527           |
# | explained_variance | 0.0578         |
# | fps                | 782            |
# | nupdates           | 10             |
# | policy_entropy     | 1.0779436      |
# | policy_loss        | -0.00033783642 |
# | serial_timesteps   | 1280           |
# | time_elapsed       | 53.8           |
# | total_timesteps    | 40960          |
# | value_loss         | 0.063737206    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0017345957  |
# | clipfrac           | 0.0686914     |
# | eplenmean          | 213           |
# | eprewmean          | -527          |
# | explained_variance | 0.0199        |
# | fps                | 770           |
# | nupdates           | 11            |
# | policy_entropy     | 1.0722497     |
# | policy_loss        | -0.0011086795 |
# | serial_timesteps   | 1408          |
# | time_elapsed       | 59.1          |
# | total_timesteps    | 45056         |
# | value_loss         | 0.067037195   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0013369535  |
# | clipfrac           | 0.04583008    |
# | eplenmean          | 209           |
# | eprewmean          | -527          |
# | explained_variance | -0.00102      |
# | fps                | 796           |
# | nupdates           | 12            |
# | policy_entropy     | 1.0737453     |
# | policy_loss        | 4.9651604e-05 |
# | serial_timesteps   | 1536          |
# | time_elapsed       | 64.2          |
# | total_timesteps    | 49152         |
# | value_loss         | 0.054857593   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0018932332  |
# | clipfrac           | 0.073564455   |
# | eplenmean          | 200           |
# | eprewmean          | -527          |
# | explained_variance | 0.043         |
# | fps                | 785           |
# | nupdates           | 13            |
# | policy_entropy     | 1.0662096     |
# | policy_loss        | -0.0008292411 |
# | serial_timesteps   | 1664          |
# | time_elapsed       | 69.4          |
# | total_timesteps    | 53248         |
# | value_loss         | 0.060370706   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0020687236  |
# | clipfrac           | 0.07727539    |
# | eplenmean          | 204           |
# | eprewmean          | -525          |
# | explained_variance | 0.0157        |
# | fps                | 768           |
# | nupdates           | 14            |
# | policy_entropy     | 1.0594614     |
# | policy_loss        | -0.0006887268 |
# | serial_timesteps   | 1792          |
# | time_elapsed       | 74.8          |
# | total_timesteps    | 57344         |
# | value_loss         | 0.05905364    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0018217039   |
# | clipfrac           | 0.059023436    |
# | eplenmean          | 221            |
# | eprewmean          | -524           |
# | explained_variance | 0.00348        |
# | fps                | 775            |
# | nupdates           | 15             |
# | policy_entropy     | 1.0548551      |
# | policy_loss        | -0.00042630904 |
# | serial_timesteps   | 1920           |
# | time_elapsed       | 80.1           |
# | total_timesteps    | 61440          |
# | value_loss         | 0.058117714    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.0018177493   |
# | clipfrac           | 0.060859375    |
# | eplenmean          | 227            |
# | eprewmean          | -524           |
# | explained_variance | 0.0277         |
# | fps                | 768            |
# | nupdates           | 16             |
# | policy_entropy     | 1.0555301      |
# | policy_loss        | -0.00079562917 |
# | serial_timesteps   | 2048           |
# | time_elapsed       | 85.4           |
# | total_timesteps    | 65536          |
# | value_loss         | 0.06048264     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0016491242  |
# | clipfrac           | 0.05288086    |
# | eplenmean          | 226           |
# | eprewmean          | -523          |
# | explained_variance | 0.0223        |
# | fps                | 809           |
# | nupdates           | 17            |
# | policy_entropy     | 1.0531591     |
# | policy_loss        | 4.8336365e-06 |
# | serial_timesteps   | 2176          |
# | time_elapsed       | 90.4          |
# | total_timesteps    | 69632         |
# | value_loss         | 0.062385667   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0012891763   |
# | clipfrac           | 0.028710937    |
# | eplenmean          | 241            |
# | eprewmean          | -524           |
# | explained_variance | 0.0573         |
# | fps                | 808            |
# | nupdates           | 18             |
# | policy_entropy     | 1.0520506      |
# | policy_loss        | 0.000104945844 |
# | serial_timesteps   | 2304           |
# | time_elapsed       | 95.5           |
# | total_timesteps    | 73728          |
# | value_loss         | 0.06775955     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.0018072968   |
# | clipfrac           | 0.06460938     |
# | eplenmean          | 244            |
# | eprewmean          | -524           |
# | explained_variance | 0.0407         |
# | fps                | 797            |
# | nupdates           | 19             |
# | policy_entropy     | 1.0413175      |
# | policy_loss        | -0.00069180405 |
# | serial_timesteps   | 2432           |
# | time_elapsed       | 101            |
# | total_timesteps    | 77824          |
# | value_loss         | 0.057331488    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.0016625599   |
# | clipfrac           | 0.051230468    |
# | eplenmean          | 231            |
# | eprewmean          | -525           |
# | explained_variance | 0.0156         |
# | fps                | 783            |
# | nupdates           | 20             |
# | policy_entropy     | 1.036376       |
# | policy_loss        | -0.00014022182 |
# | serial_timesteps   | 2560           |
# | time_elapsed       | 106            |
# | total_timesteps    | 81920          |
# | value_loss         | 0.06494482     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0014977934  |
# | clipfrac           | 0.039921876   |
# | eplenmean          | 234           |
# | eprewmean          | -525          |
# | explained_variance | 0.0368        |
# | fps                | 814           |
# | nupdates           | 21            |
# | policy_entropy     | 1.0393872     |
# | policy_loss        | 0.00019949455 |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 111           |
# | total_timesteps    | 86016         |
# | value_loss         | 0.06893089    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0027910268  |
# | clipfrac           | 0.11341797    |
# | eplenmean          | 226           |
# | eprewmean          | -526          |
# | explained_variance | 0.00254       |
# | fps                | 797           |
# | nupdates           | 22            |
# | policy_entropy     | 1.0261965     |
# | policy_loss        | -0.0017732327 |
# | serial_timesteps   | 2816          |
# | time_elapsed       | 116           |
# | total_timesteps    | 90112         |
# | value_loss         | 0.06451815    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0022715467  |
# | clipfrac           | 0.07792969    |
# | eplenmean          | 226           |
# | eprewmean          | -525          |
# | explained_variance | -0.000195     |
# | fps                | 785           |
# | nupdates           | 23            |
# | policy_entropy     | 1.0220321     |
# | policy_loss        | -0.0014681839 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 121           |
# | total_timesteps    | 94208         |
# | value_loss         | 0.07277915    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0018691702   |
# | clipfrac           | 0.05763672     |
# | eplenmean          | 227            |
# | eprewmean          | -525           |
# | explained_variance | -0.00781       |
# | fps                | 796            |
# | nupdates           | 24             |
# | policy_entropy     | 1.0297222      |
# | policy_loss        | -0.00077810243 |
# | serial_timesteps   | 3072           |
# | time_elapsed       | 126            |
# | total_timesteps    | 98304          |
# | value_loss         | 0.054793935    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.002116893   |
# | clipfrac           | 0.07583985    |
# | eplenmean          | 235           |
# | eprewmean          | -526          |
# | explained_variance | -0.0177       |
# | fps                | 781           |
# | nupdates           | 25            |
# | policy_entropy     | 1.023567      |
# | policy_loss        | -0.0010069077 |
# | serial_timesteps   | 3200          |
# | time_elapsed       | 132           |
# | total_timesteps    | 102400        |
# | value_loss         | 0.061056063   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.002062644    |
# | clipfrac           | 0.06352539     |
# | eplenmean          | 234            |
# | eprewmean          | -525           |
# | explained_variance | 0.0212         |
# | fps                | 801            |
# | nupdates           | 26             |
# | policy_entropy     | 1.0172509      |
# | policy_loss        | -0.00065830373 |
# | serial_timesteps   | 3328           |
# | time_elapsed       | 137            |
# | total_timesteps    | 106496         |
# | value_loss         | 0.06945156     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0022470849  |
# | clipfrac           | 0.08483399    |
# | eplenmean          | 239           |
# | eprewmean          | -525          |
# | explained_variance | 0.0232        |
# | fps                | 797           |
# | nupdates           | 27            |
# | policy_entropy     | 1.0085881     |
# | policy_loss        | -0.0014661613 |
# | serial_timesteps   | 3456          |
# | time_elapsed       | 142           |
# | total_timesteps    | 110592        |
# | value_loss         | 0.07628484    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0017026842   |
# | clipfrac           | 0.047060546    |
# | eplenmean          | 249            |
# | eprewmean          | -524           |
# | explained_variance | 0.00729        |
# | fps                | 792            |
# | nupdates           | 28             |
# | policy_entropy     | 1.0131191      |
# | policy_loss        | -0.00018720294 |
# | serial_timesteps   | 3584           |
# | time_elapsed       | 147            |
# | total_timesteps    | 114688         |
# | value_loss         | 0.059608735    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0020274615  |
# | clipfrac           | 0.081318356   |
# | eplenmean          | 241           |
# | eprewmean          | -524          |
# | explained_variance | 0.0169        |
# | fps                | 770           |
# | nupdates           | 29            |
# | policy_entropy     | 1.0051094     |
# | policy_loss        | -0.0011492603 |
# | serial_timesteps   | 3712          |
# | time_elapsed       | 152           |
# | total_timesteps    | 118784        |
# | value_loss         | 0.060510572   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0022354862 |
# | clipfrac           | 0.09726562   |
# | eplenmean          | 237          |
# | eprewmean          | -524         |
# | explained_variance | -0.0193      |
# | fps                | 792          |
# | nupdates           | 30           |
# | policy_entropy     | 1.0024827    |
# | policy_loss        | -0.001331069 |
# | serial_timesteps   | 3840         |
# | time_elapsed       | 158          |
# | total_timesteps    | 122880       |
# | value_loss         | 0.06523297   |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.0019946345   |
# | clipfrac           | 0.06404297     |
# | eplenmean          | 229            |
# | eprewmean          | -523           |
# | explained_variance | 0.0245         |
# | fps                | 785            |
# | nupdates           | 31             |
# | policy_entropy     | 1.0061764      |
# | policy_loss        | -0.00029942664 |
# | serial_timesteps   | 3968           |
# | time_elapsed       | 163            |
# | total_timesteps    | 126976         |
# | value_loss         | 0.06331863     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.0022704226   |
# | clipfrac           | 0.082177736    |
# | eplenmean          | 237            |
# | eprewmean          | -523           |
# | explained_variance | -0.0228        |
# | fps                | 793            |
# | nupdates           | 32             |
# | policy_entropy     | 0.98857826     |
# | policy_loss        | -0.00016328393 |
# | serial_timesteps   | 4096           |
# | time_elapsed       | 168            |
# | total_timesteps    | 131072         |
# | value_loss         | 0.05792456     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0022000556  |
# | clipfrac           | 0.07029297    |
# | eplenmean          | 246           |
# | eprewmean          | -524          |
# | explained_variance | 0.0192        |
# | fps                | 794           |
# | nupdates           | 33            |
# | policy_entropy     | 1.000302      |
# | policy_loss        | -3.529533e-05 |
# | serial_timesteps   | 4224          |
# | time_elapsed       | 173           |
# | total_timesteps    | 135168        |
# | value_loss         | 0.06257701    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0023285646 |
# | clipfrac           | 0.06783203   |
# | eplenmean          | 256          |
# | eprewmean          | -524         |
# | explained_variance | -0.0211      |
# | fps                | 792          |
# | nupdates           | 34           |
# | policy_entropy     | 0.99573684   |
# | policy_loss        | 0.0004641657 |
# | serial_timesteps   | 4352         |
# | time_elapsed       | 178          |
# | total_timesteps    | 139264       |
# | value_loss         | 0.05490368   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0018301315  |
# | clipfrac           | 0.06962891    |
# | eplenmean          | 253           |
# | eprewmean          | -525          |
# | explained_variance | 0.0131        |
# | fps                | 791           |
# | nupdates           | 35            |
# | policy_entropy     | 0.99975044    |
# | policy_loss        | -0.0005887733 |
# | serial_timesteps   | 4480          |
# | time_elapsed       | 183           |
# | total_timesteps    | 143360        |
# | value_loss         | 0.05250059    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0022520404 |
# | clipfrac           | 0.07429688   |
# | eplenmean          | 278          |
# | eprewmean          | -526         |
# | explained_variance | -0.0135      |
# | fps                | 804          |
# | nupdates           | 36           |
# | policy_entropy     | 0.9976485    |
# | policy_loss        | -0.000425103 |
# | serial_timesteps   | 4608         |
# | time_elapsed       | 189          |
# | total_timesteps    | 147456       |
# | value_loss         | 0.061411504  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0022393859  |
# | clipfrac           | 0.09395508    |
# | eplenmean          | 269           |
# | eprewmean          | -527          |
# | explained_variance | -0.00388      |
# | fps                | 809           |
# | nupdates           | 37            |
# | policy_entropy     | 1.003889      |
# | policy_loss        | -0.0017800214 |
# | serial_timesteps   | 4736          |
# | time_elapsed       | 194           |
# | total_timesteps    | 151552        |
# | value_loss         | 0.052865453   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0029382766  |
# | clipfrac           | 0.10924805    |
# | eplenmean          | 279           |
# | eprewmean          | -528          |
# | explained_variance | -0.00125      |
# | fps                | 802           |
# | nupdates           | 38            |
# | policy_entropy     | 1.0018176     |
# | policy_loss        | -0.0019204665 |
# | serial_timesteps   | 4864          |
# | time_elapsed       | 199           |
# | total_timesteps    | 155648        |
# | value_loss         | 0.067274116   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0019791455   |
# | clipfrac           | 0.06490234     |
# | eplenmean          | 270            |
# | eprewmean          | -526           |
# | explained_variance | 0.0097         |
# | fps                | 791            |
# | nupdates           | 39             |
# | policy_entropy     | 1.00322        |
# | policy_loss        | -3.9794333e-05 |
# | serial_timesteps   | 4992           |
# | time_elapsed       | 204            |
# | total_timesteps    | 159744         |
# | value_loss         | 0.06326213     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0020073717  |
# | clipfrac           | 0.06961914    |
# | eplenmean          | 253           |
# | eprewmean          | -526          |
# | explained_variance | 0.0138        |
# | fps                | 788           |
# | nupdates           | 40            |
# | policy_entropy     | 0.9931512     |
# | policy_loss        | 0.00015377186 |
# | serial_timesteps   | 5120          |
# | time_elapsed       | 209           |
# | total_timesteps    | 163840        |
# | value_loss         | 0.058127433   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0021428992 |
# | clipfrac           | 0.07900391   |
# | eplenmean          | 264          |
# | eprewmean          | -526         |
# | explained_variance | 0.00247      |
# | fps                | 781          |
# | nupdates           | 41           |
# | policy_entropy     | 0.9927835    |
# | policy_loss        | -0.000425024 |
# | serial_timesteps   | 5248         |
# | time_elapsed       | 214          |
# | total_timesteps    | 167936       |
# | value_loss         | 0.06142547   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0024014576  |
# | clipfrac           | 0.067128904   |
# | eplenmean          | 257           |
# | eprewmean          | -526          |
# | explained_variance | 0.0119        |
# | fps                | 786           |
# | nupdates           | 42            |
# | policy_entropy     | 0.99445915    |
# | policy_loss        | -0.0009760527 |
# | serial_timesteps   | 5376          |
# | time_elapsed       | 220           |
# | total_timesteps    | 172032        |
# | value_loss         | 0.06580107    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.001771481  |
# | clipfrac           | 0.056962892  |
# | eplenmean          | 257          |
# | eprewmean          | -526         |
# | explained_variance | 0.0319       |
# | fps                | 769          |
# | nupdates           | 43           |
# | policy_entropy     | 0.99385065   |
# | policy_loss        | 0.0006580582 |
# | serial_timesteps   | 5504         |
# | time_elapsed       | 225          |
# | total_timesteps    | 176128       |
# | value_loss         | 0.062310237  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0021229656 |
# | clipfrac           | 0.08518555   |
# | eplenmean          | 268          |
# | eprewmean          | -527         |
# | explained_variance | -0.014       |
# | fps                | 757          |
# | nupdates           | 44           |
# | policy_entropy     | 0.9960192    |
# | policy_loss        | -0.000622154 |
# | serial_timesteps   | 5632         |
# | time_elapsed       | 230          |
# | total_timesteps    | 180224       |
# | value_loss         | 0.0598027    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0025161237  |
# | clipfrac           | 0.11679687    |
# | eplenmean          | 281           |
# | eprewmean          | -526          |
# | explained_variance | 0.0105        |
# | fps                | 757           |
# | nupdates           | 45            |
# | policy_entropy     | 0.98557633    |
# | policy_loss        | -0.0013557768 |
# | serial_timesteps   | 5760          |
# | time_elapsed       | 236           |
# | total_timesteps    | 184320        |
# | value_loss         | 0.07146577    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0022256267  |
# | clipfrac           | 0.08698242    |
# | eplenmean          | 286           |
# | eprewmean          | -526          |
# | explained_variance | -0.0201       |
# | fps                | 744           |
# | nupdates           | 46            |
# | policy_entropy     | 0.97738564    |
# | policy_loss        | -0.0007352334 |
# | serial_timesteps   | 5888          |
# | time_elapsed       | 241           |
# | total_timesteps    | 188416        |
# | value_loss         | 0.056472637   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.002339946   |
# | clipfrac           | 0.10107422    |
# | eplenmean          | 297           |
# | eprewmean          | -526          |
# | explained_variance | 0.000602      |
# | fps                | 782           |
# | nupdates           | 47            |
# | policy_entropy     | 0.97208893    |
# | policy_loss        | -0.0006290168 |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 246           |
# | total_timesteps    | 192512        |
# | value_loss         | 0.052111834   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0022021153  |
# | clipfrac           | 0.092617184   |
# | eplenmean          | 303           |
# | eprewmean          | -525          |
# | explained_variance | 0.00753       |
# | fps                | 786           |
# | nupdates           | 48            |
# | policy_entropy     | 0.9619896     |
# | policy_loss        | -0.0013418288 |
# | serial_timesteps   | 6144          |
# | time_elapsed       | 252           |
# | total_timesteps    | 196608        |
# | value_loss         | 0.059133243   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0023408625  |
# | clipfrac           | 0.10383789    |
# | eplenmean          | 312           |
# | eprewmean          | -526          |
# | explained_variance | -0.0212       |
# | fps                | 767           |
# | nupdates           | 49            |
# | policy_entropy     | 0.9617701     |
# | policy_loss        | -0.0009750239 |
# | serial_timesteps   | 6272          |
# | time_elapsed       | 257           |
# | total_timesteps    | 200704        |
# | value_loss         | 0.07008824    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0019959102  |
# | clipfrac           | 0.07552734    |
# | eplenmean          | 298           |
# | eprewmean          | -525          |
# | explained_variance | -0.0113       |
# | fps                | 763           |
# | nupdates           | 50            |
# | policy_entropy     | 0.9684668     |
# | policy_loss        | 0.00044761357 |
# | serial_timesteps   | 6400          |
# | time_elapsed       | 262           |
# | total_timesteps    | 204800        |
# | value_loss         | 0.06487238    |
# --------------------------------------
# Saving to /tmp/openai-2018-05-30-18-51-01-525742/checkpoints/00050
# --------------------------------------
# | approxkl           | 0.0022689346  |
# | clipfrac           | 0.10193359    |
# | eplenmean          | 284           |
# | eprewmean          | -525          |
# | explained_variance | 0.00433       |
# | fps                | 770           |
# | nupdates           | 51            |
# | policy_entropy     | 0.96378607    |
# | policy_loss        | -0.0013641666 |
# | serial_timesteps   | 6528          |
# | time_elapsed       | 268           |
# | total_timesteps    | 208896        |
# | value_loss         | 0.05682048    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0024112319   |
# | clipfrac           | 0.07837891     |
# | eplenmean          | 278            |
# | eprewmean          | -526           |
# | explained_variance | -0.00849       |
# | fps                | 763            |
# | nupdates           | 52             |
# | policy_entropy     | 0.954336       |
# | policy_loss        | -0.00041781008 |
# | serial_timesteps   | 6656           |
# | time_elapsed       | 273            |
# | total_timesteps    | 212992         |
# | value_loss         | 0.057844292    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.002067888    |
# | clipfrac           | 0.078964844    |
# | eplenmean          | 284            |
# | eprewmean          | -527           |
# | explained_variance | 0.00101        |
# | fps                | 773            |
# | nupdates           | 53             |
# | policy_entropy     | 0.94848967     |
# | policy_loss        | -0.00029203194 |
# | serial_timesteps   | 6784           |
# | time_elapsed       | 278            |
# | total_timesteps    | 217088         |
# | value_loss         | 0.059961937    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0024956882  |
# | clipfrac           | 0.112509765   |
# | eplenmean          | 285           |
# | eprewmean          | -527          |
# | explained_variance | -0.0241       |
# | fps                | 762           |
# | nupdates           | 54            |
# | policy_entropy     | 0.9450548     |
# | policy_loss        | -0.0014946223 |
# | serial_timesteps   | 6912          |
# | time_elapsed       | 284           |
# | total_timesteps    | 221184        |
# | value_loss         | 0.07563199    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.001864594   |
# | clipfrac           | 0.06734375    |
# | eplenmean          | 268           |
# | eprewmean          | -526          |
# | explained_variance | 0.00485       |
# | fps                | 766           |
# | nupdates           | 55            |
# | policy_entropy     | 0.9420372     |
# | policy_loss        | 0.00020042226 |
# | serial_timesteps   | 7040          |
# | time_elapsed       | 289           |
# | total_timesteps    | 225280        |
# | value_loss         | 0.059185676   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.001998164    |
# | clipfrac           | 0.08013672     |
# | eplenmean          | 262            |
# | eprewmean          | -527           |
# | explained_variance | 0.00806        |
# | fps                | 773            |
# | nupdates           | 56             |
# | policy_entropy     | 0.9355701      |
# | policy_loss        | -0.00042906933 |
# | serial_timesteps   | 7168           |
# | time_elapsed       | 294            |
# | total_timesteps    | 229376         |
# | value_loss         | 0.060326945    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.0021399246   |
# | clipfrac           | 0.078525394    |
# | eplenmean          | 268            |
# | eprewmean          | -527           |
# | explained_variance | 0.00465        |
# | fps                | 781            |
# | nupdates           | 57             |
# | policy_entropy     | 0.9422295      |
# | policy_loss        | -0.00026629522 |
# | serial_timesteps   | 7296           |
# | time_elapsed       | 300            |
# | total_timesteps    | 233472         |
# | value_loss         | 0.0663784      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.001646881    |
# | clipfrac           | 0.0525         |
# | eplenmean          | 286            |
# | eprewmean          | -526           |
# | explained_variance | 0.00973        |
# | fps                | 803            |
# | nupdates           | 58             |
# | policy_entropy     | 0.9511803      |
# | policy_loss        | -0.00019617962 |
# | serial_timesteps   | 7424           |
# | time_elapsed       | 305            |
# | total_timesteps    | 237568         |
# | value_loss         | 0.05399874     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.0026869373   |
# | clipfrac           | 0.120322265    |
# | eplenmean          | 284            |
# | eprewmean          | -526           |
# | explained_variance | 0.00913        |
# | fps                | 771            |
# | nupdates           | 59             |
# | policy_entropy     | 0.9303847      |
# | policy_loss        | -0.00088686356 |
# | serial_timesteps   | 7552           |
# | time_elapsed       | 310            |
# | total_timesteps    | 241664         |
# | value_loss         | 0.05451686     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0019776085  |
# | clipfrac           | 0.069472656   |
# | eplenmean          | 279           |
# | eprewmean          | -525          |
# | explained_variance | 0.0111        |
# | fps                | 766           |
# | nupdates           | 60            |
# | policy_entropy     | 0.9312289     |
# | policy_loss        | -6.109848e-05 |
# | serial_timesteps   | 7680          |
# | time_elapsed       | 315           |
# | total_timesteps    | 245760        |
# | value_loss         | 0.051244713   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0022061523  |
# | clipfrac           | 0.087763675   |
# | eplenmean          | 282           |
# | eprewmean          | -524          |
# | explained_variance | -0.0122       |
# | fps                | 752           |
# | nupdates           | 61            |
# | policy_entropy     | 0.9346799     |
# | policy_loss        | -0.0006727616 |
# | serial_timesteps   | 7808          |
# | time_elapsed       | 321           |
# | total_timesteps    | 249856        |
# | value_loss         | 0.05566014    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0024623899  |
# | clipfrac           | 0.119208984   |
# | eplenmean          | 293           |
# | eprewmean          | -524          |
# | explained_variance | -0.00358      |
# | fps                | 769           |
# | nupdates           | 62            |
# | policy_entropy     | 0.927557      |
# | policy_loss        | -0.0016687154 |
# | serial_timesteps   | 7936          |
# | time_elapsed       | 326           |
# | total_timesteps    | 253952        |
# | value_loss         | 0.047910105   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0021058004  |
# | clipfrac           | 0.08458008    |
# | eplenmean          | 292           |
# | eprewmean          | -524          |
# | explained_variance | 0.00393       |
# | fps                | 768           |
# | nupdates           | 63            |
# | policy_entropy     | 0.91775584    |
# | policy_loss        | -0.0005945946 |
# | serial_timesteps   | 8064          |
# | time_elapsed       | 331           |
# | total_timesteps    | 258048        |
# | value_loss         | 0.05406882    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0016378675  |
# | clipfrac           | 0.040664062   |
# | eplenmean          | 307           |
# | eprewmean          | -524          |
# | explained_variance | 0.00834       |
# | fps                | 770           |
# | nupdates           | 64            |
# | policy_entropy     | 0.9237263     |
# | policy_loss        | 0.00049242727 |
# | serial_timesteps   | 8192          |
# | time_elapsed       | 337           |
# | total_timesteps    | 262144        |
# | value_loss         | 0.057735346   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0018158751  |
# | clipfrac           | 0.06732422    |
# | eplenmean          | 294           |
# | eprewmean          | -525          |
# | explained_variance | 0.00139       |
# | fps                | 764           |
# | nupdates           | 65            |
# | policy_entropy     | 0.918839      |
# | policy_loss        | -0.0005327172 |
# | serial_timesteps   | 8320          |
# | time_elapsed       | 342           |
# | total_timesteps    | 266240        |
# | value_loss         | 0.054838993   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0020434642   |
# | clipfrac           | 0.07496094     |
# | eplenmean          | 307            |
# | eprewmean          | -524           |
# | explained_variance | 0.00299        |
# | fps                | 765            |
# | nupdates           | 66             |
# | policy_entropy     | 0.9163018      |
# | policy_loss        | -0.00059232366 |
# | serial_timesteps   | 8448           |
# | time_elapsed       | 347            |
# | total_timesteps    | 270336         |
# | value_loss         | 0.057001147    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0020117096  |
# | clipfrac           | 0.07736328    |
# | eplenmean          | 309           |
# | eprewmean          | -524          |
# | explained_variance | -0.00523      |
# | fps                | 774           |
# | nupdates           | 67            |
# | policy_entropy     | 0.9079886     |
# | policy_loss        | -0.0012906209 |
# | serial_timesteps   | 8576          |
# | time_elapsed       | 353           |
# | total_timesteps    | 274432        |
# | value_loss         | 0.057365976   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0017046849  |
# | clipfrac           | 0.057109375   |
# | eplenmean          | 309           |
# | eprewmean          | -524          |
# | explained_variance | 0.00768       |
# | fps                | 768           |
# | nupdates           | 68            |
# | policy_entropy     | 0.9104399     |
# | policy_loss        | -0.0004232038 |
# | serial_timesteps   | 8704          |
# | time_elapsed       | 358           |
# | total_timesteps    | 278528        |
# | value_loss         | 0.048269883   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0019949167  |
# | clipfrac           | 0.06585938    |
# | eplenmean          | 303           |
# | eprewmean          | -525          |
# | explained_variance | 0.00385       |
# | fps                | 765           |
# | nupdates           | 69            |
# | policy_entropy     | 0.9089935     |
# | policy_loss        | -0.0007317748 |
# | serial_timesteps   | 8832          |
# | time_elapsed       | 363           |
# | total_timesteps    | 282624        |
# | value_loss         | 0.06101705    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0016154668   |
# | clipfrac           | 0.069902346    |
# | eplenmean          | 305            |
# | eprewmean          | -524           |
# | explained_variance | 0.0084         |
# | fps                | 758            |
# | nupdates           | 70             |
# | policy_entropy     | 0.90733474     |
# | policy_loss        | -0.00042029918 |
# | serial_timesteps   | 8960           |
# | time_elapsed       | 369            |
# | total_timesteps    | 286720         |
# | value_loss         | 0.05452142     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0021243433  |
# | clipfrac           | 0.09387695    |
# | eplenmean          | 308           |
# | eprewmean          | -524          |
# | explained_variance | -0.002        |
# | fps                | 769           |
# | nupdates           | 71            |
# | policy_entropy     | 0.9062597     |
# | policy_loss        | -0.0017363387 |
# | serial_timesteps   | 9088          |
# | time_elapsed       | 374           |
# | total_timesteps    | 290816        |
# | value_loss         | 0.054917336   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0015753494  |
# | clipfrac           | 0.060371093   |
# | eplenmean          | 299           |
# | eprewmean          | -524          |
# | explained_variance | 0.0223        |
# | fps                | 768           |
# | nupdates           | 72            |
# | policy_entropy     | 0.9155499     |
# | policy_loss        | -0.0011191005 |
# | serial_timesteps   | 9216          |
# | time_elapsed       | 379           |
# | total_timesteps    | 294912        |
# | value_loss         | 0.06407136    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0022015052 |
# | clipfrac           | 0.0925293    |
# | eplenmean          | 317          |
# | eprewmean          | -523         |
# | explained_variance | 0.00248      |
# | fps                | 771          |
# | nupdates           | 73           |
# | policy_entropy     | 0.92130095   |
# | policy_loss        | -0.001852472 |
# | serial_timesteps   | 9344         |
# | time_elapsed       | 385          |
# | total_timesteps    | 299008       |
# | value_loss         | 0.06522606   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0015283034  |
# | clipfrac           | 0.06253906    |
# | eplenmean          | 307           |
# | eprewmean          | -523          |
# | explained_variance | 0.000109      |
# | fps                | 767           |
# | nupdates           | 74            |
# | policy_entropy     | 0.9207677     |
# | policy_loss        | -6.340076e-05 |
# | serial_timesteps   | 9472          |
# | time_elapsed       | 390           |
# | total_timesteps    | 303104        |
# | value_loss         | 0.053993702   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0023047298  |
# | clipfrac           | 0.09280273    |
# | eplenmean          | 314           |
# | eprewmean          | -523          |
# | explained_variance | -0.0142       |
# | fps                | 759           |
# | nupdates           | 75            |
# | policy_entropy     | 0.9101105     |
# | policy_loss        | -0.0011328561 |
# | serial_timesteps   | 9600          |
# | time_elapsed       | 396           |
# | total_timesteps    | 307200        |
# | value_loss         | 0.04664341    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0023109952  |
# | clipfrac           | 0.08015625    |
# | eplenmean          | 303           |
# | eprewmean          | -524          |
# | explained_variance | -0.00501      |
# | fps                | 763           |
# | nupdates           | 76            |
# | policy_entropy     | 0.9112576     |
# | policy_loss        | -0.0011184089 |
# | serial_timesteps   | 9728          |
# | time_elapsed       | 401           |
# | total_timesteps    | 311296        |
# | value_loss         | 0.061140623   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0017650297  |
# | clipfrac           | 0.07663086    |
# | eplenmean          | 313           |
# | eprewmean          | -523          |
# | explained_variance | -0.0121       |
# | fps                | 765           |
# | nupdates           | 77            |
# | policy_entropy     | 0.9089383     |
# | policy_loss        | -0.0011640276 |
# | serial_timesteps   | 9856          |
# | time_elapsed       | 406           |
# | total_timesteps    | 315392        |
# | value_loss         | 0.047781184   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0025292146  |
# | clipfrac           | 0.08152344    |
# | eplenmean          | 331           |
# | eprewmean          | -524          |
# | explained_variance | -0.00658      |
# | fps                | 767           |
# | nupdates           | 78            |
# | policy_entropy     | 0.89899236    |
# | policy_loss        | -0.0011503341 |
# | serial_timesteps   | 9984          |
# | time_elapsed       | 412           |
# | total_timesteps    | 319488        |
# | value_loss         | 0.060299672   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0020627922  |
# | clipfrac           | 0.08223633    |
# | eplenmean          | 332           |
# | eprewmean          | -524          |
# | explained_variance | -0.0201       |
# | fps                | 743           |
# | nupdates           | 79            |
# | policy_entropy     | 0.89325786    |
# | policy_loss        | -0.0012397819 |
# | serial_timesteps   | 10112         |
# | time_elapsed       | 417           |
# | total_timesteps    | 323584        |
# | value_loss         | 0.054422747   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0022952245 |
# | clipfrac           | 0.1124707    |
# | eplenmean          | 327          |
# | eprewmean          | -524         |
# | explained_variance | -0.00184     |
# | fps                | 766          |
# | nupdates           | 80           |
# | policy_entropy     | 0.8876499    |
# | policy_loss        | -0.001847313 |
# ...
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/repos/baselines/baselines/common/vec_env/subproc_vec_env.py", line 10, in worker
#     cmd, data = remote.recv()
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/projects/algotrading/notebooks/src/common/environments.py", line 115, in _get_observation
#     df = df.loc[:,['open','high','low','close','ema','sin_time','cos_time']]
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/projects/algotrading/notebooks/src/common/environments.py", line 207, in step
#     position=self._position)
# KeyboardInterrupt
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
# KeyboardInterrupt
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/pandas/core/indexing.py", line 1325, in __getitem__
#     return self._getitem_tuple(key)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/ubuntu/projects/algotrading/notebooks/src/common/environments.py", line 115, in _get_observation
#     df = df.loc[:,['open','high','low','close','ema','sin_time','cos_time']]
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/pandas/core/indexing.py", line 841, in _getitem_tuple
#     self._has_valid_tuple(tup)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-9840ce4dbb52> in <module>()
#       1 logger.configure()
#       2
# ----> 3 train('tradingenv-v0', num_timesteps=1e7, seed=0, policy='cnn')
#
# <ipython-input-4-7251243358d5> in train(env_id, num_timesteps, seed, policy)
#      29         lr=2.5e-4,
#      30         cliprange=0.1,
# ---> 31         total_timesteps=int(num_timesteps * 1.1))
#
# ~/repos/baselines/baselines/ppo2/ppo2.py in learn(policy, env, nsteps, total_timesteps, ent_coef, lr, vf_coef, max_grad_norm, gamma, lam, log_interval, nminibatches, noptepochs, cliprange, save_interval, load_path)
#     189         lrnow = lr(frac)
#     190         cliprangenow = cliprange(frac)
# --> 191         obs, returns, masks, actions, values, neglogpacs, states, epinfos = runner.run() #pylint: disable=E0632
#     192         epinfobuf.extend(epinfos)
#     193         mblossvals = []
#
# ~/repos/baselines/baselines/ppo2/ppo2.py in run(self)
#     104             mb_neglogpacs.append(neglogpacs)
#     105             mb_dones.append(self.dones)
# --> 106             self.obs[:], rewards, self.dones, infos = self.env.step(actions)
#     107
#     108             #self.env.venv.render()
#
# ~/repos/baselines/baselines/common/vec_env/__init__.py in step(self, actions)
#      75
#      76     def step(self, actions):
# ---> 77         self.step_async(actions)
#      78         return self.step_wait()
#      79
#
# ~/repos/baselines/baselines/common/vec_env/__init__.py in step_async(self, actions)
#      97
#      98     def step_async(self, actions):
# ---> 99         self.venv.step_async(actions)
#     100
#     101     @abstractmethod
#
# ~/repos/baselines/baselines/common/vec_env/subproc_vec_env.py in step_async(self, actions)
#      54     def step_async(self, actions):
#      55         for remote, action in zip(self.remotes, actions):
# ---> 56             remote.send(('step', action))
#      57         self.waiting = True
#      58
#
# ~/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py in send(self, obj)
#     204         self._check_closed()
#     205         self._check_writable()
# --> 206         self._send_bytes(_ForkingPickler.dumps(obj))
#     207
#     208     def recv_bytes(self, maxlength=None):
#
# ~/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/reduction.py in dumps(cls, obj, protocol)
#      48     @classmethod
#      49     def dumps(cls, obj, protocol=None):
# ---> 50         buf = io.BytesIO()
#      51         cls(buf, protocol).dump(obj)
#      52         return buf.getbuffer()
#
# KeyboardInterrupt:
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/pandas/core/indexing.py", line 189, in _has_valid_tuple
#     if not self._has_valid_type(k, i):
# KeyboardInterrupt
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/pandas/core/indexing.py", line 1325, in __getitem__
#     return self._getitem_tuple(key)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/pandas/core/indexing.py", line 1415, in _has_valid_type
#     np.all(ax.get_indexer_for(key) < 0)):
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/pandas/core/indexing.py", line 841, in _getitem_tuple
#     self._has_valid_tuple(tup)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/pandas/core/indexing.py", line 189, in _has_valid_tuple
#     if not self._has_valid_type(k, i):
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 2717, in get_indexer_for
#     return self.get_indexer(target, **kwargs)
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/pandas/core/indexing.py", line 1415, in _has_valid_type
#     np.all(ax.get_indexer_for(key) < 0)):
#   File "/home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 2598, in get_indexer
#     indexer = self._engine.get_indexer(target._values)
# KeyboardInterrupt
# KeyboardInterrupt

# %%
load_path = '/tmp/openai-2018-05-29-15-08-04-310254/checkpoints/00100'
logger.get_dir()
# Out:
# '/tmp/openai-2018-05-29-15-08-04-310254'

# %%
def test(env_id, load_path, seed):

    ncpu = multiprocessing.cpu_count()
    if sys.platform == 'darwin': ncpu //= 2
    config = tf.ConfigProto(allow_soft_placement=True,
                            intra_op_parallelism_threads=ncpu,
                            inter_op_parallelism_threads=ncpu)
    config.gpu_options.allow_growth = True #pylint: disable=E1101
    tf.Session(config=config).__enter__()
    
    def make_env():
        env = gym.make(env_id)
        return env
    
    
    env = DummyVecEnv([make_env])
    running_mean = np.load('{}/mean.npy'.format(load_path))
    running_var = np.load('{}/var.npy'.format(load_path))
    env = VecNormalizeTest(env, running_mean, running_var)
    set_global_seeds(seed)

    policy = CnnPolicy
    ob_space = env.venv.observation_space
    ac_space = env.venv.action_space
    nbatch_act = 1 * 1
    nbatch_train = 32 * 1
    nsteps = 128
    ent_coef = .01
    vf_coef = 0.5
    max_grad_norm = 0.5
    make_model = lambda : ppo2.Model(policy=policy, ob_space=ob_space, ac_space=ac_space, 
                                nbatch_act=nbatch_act, nbatch_train=nbatch_train, nsteps=nsteps, 
                                ent_coef=ent_coef, vf_coef=vf_coef, max_grad_norm=max_grad_norm)
    model = make_model()
    model.load(load_path + '/checkpoints/02150')
    
    obs = env.reset()
    while True:
        actions, _, _, _, = model.step(obs)
        obs[:], _, _, _, = env.step(actions)
        env.venv.render()

# %%
load_path = '../data/processed'
load_path = '/tmp/openai-2018-05-30-18-51-01-525742'
test('tradingenv-v0', load_path, seed=0)
# Out:
# WARNING:tensorflow:From /home/ubuntu/repos/baselines/baselines/common/distributions.py:148: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# WARNING:tensorflow:From /home/ubuntu/repos/baselines/baselines/common/distributions.py:159: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/ubuntu/repos/baselines/baselines/common/distributions.py:161: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
def make_env():
        env = gym.make('tradingenv-v0')
        return env
env = DummyVecEnv([make_env])
load_path = '/tmp/openai-2018-05-29-15-08-04-310254'
running_mean = np.load('{}/mean.npy'.format(load_path))
running_var = np.load('{}/var.npy'.format(load_path))
env = VecNormalizeTest(env, running_mean, running_var)

# %%
import gym
e = gym.make('tradingenv-v5')

# %%
e.step(1)
# Out:
# (array([[ 2.44675000e+03,  2.44800000e+03,  2.44675000e+03,
#           2.44725000e+03, -8.43391446e-01, -5.37299608e-01,
#           0.00000000e+00],
#         [ 2.44725000e+03,  2.44800000e+03,  2.44675000e+03,
#           2.44700000e+03, -8.54911871e-01, -5.18773258e-01,
#           0.00000000e+00],
#         [ 2.44700000e+03,  2.44775000e+03,  2.44675000e+03,
#           2.44700000e+03, -8.66025404e-01, -5.00000000e-01,
#           0.00000000e+00],
#         [ 2.44725000e+03,  2.44875000e+03,  2.44700000e+03,
#           2.44775000e+03, -8.76726756e-01, -4.80988769e-01,
#           0.00000000e+00],
#         [ 2.44800000e+03,  2.44925000e+03,  2.44775000e+03,
#           2.44850000e+03, -8.87010833e-01, -4.61748613e-01,
#           0.00000000e+00],
#         [ 2.44850000e+03,  2.44950000e+03,  2.44850000e+03,
#           2.44900000e+03, -8.96872742e-01, -4.42288690e-01,
#           0.00000000e+00],
#         [ 2.44900000e+03,  2.44950000e+03,  2.44850000e+03,
#           2.44850000e+03, -9.06307787e-01, -4.22618262e-01,
#           0.00000000e+00],
#         [ 2.44875000e+03,  2.44875000e+03,  2.44775000e+03,
#           2.44800000e+03, -9.15311479e-01, -4.02746690e-01,
#           0.00000000e+00],
#         [ 2.44800000e+03,  2.44825000e+03,  2.44725000e+03,
#           2.44775000e+03, -9.23879533e-01, -3.82683432e-01,
#           0.00000000e+00],
#         [ 2.44775000e+03,  2.44800000e+03,  2.44725000e+03,
#           2.44750000e+03, -9.32007869e-01, -3.62438038e-01,
#           0.00000000e+00],
#         [ 2.44750000e+03,  2.44775000e+03,  2.44675000e+03,
#           2.44675000e+03, -9.39692621e-01, -3.42020143e-01,
#           0.00000000e+00],
#         [ 2.44675000e+03,  2.44750000e+03,  2.44675000e+03,
#           2.44725000e+03, -9.46930129e-01, -3.21439465e-01,
#           0.00000000e+00],
#         [ 2.44750000e+03,  2.44775000e+03,  2.44675000e+03,
#           2.44750000e+03, -9.53716951e-01, -3.00705800e-01,
#           0.00000000e+00],
#         [ 2.44750000e+03,  2.44800000e+03,  2.44725000e+03,
#           2.44725000e+03, -9.60049854e-01, -2.79829014e-01,
#           0.00000000e+00],
#         [ 2.44725000e+03,  2.44850000e+03,  2.44725000e+03,
#           2.44800000e+03, -9.65925826e-01, -2.58819045e-01,
#           0.00000000e+00],
#         [ 2.44825000e+03,  2.44950000e+03,  2.44800000e+03,
#           2.44925000e+03, -9.71342070e-01, -2.37685892e-01,
#           0.00000000e+00],
#         [ 2.44925000e+03,  2.44925000e+03,  2.44825000e+03,
#           2.44850000e+03, -9.76296007e-01, -2.16439614e-01,
#           0.00000000e+00],
#         [ 2.44875000e+03,  2.44925000e+03,  2.44850000e+03,
#           2.44900000e+03, -9.80785280e-01, -1.95090322e-01,
#           0.00000000e+00],
#         [ 2.44925000e+03,  2.44925000e+03,  2.44800000e+03,
#           2.44850000e+03, -9.84807753e-01, -1.73648178e-01,
#           0.00000000e+00],
#         [ 2.44825000e+03,  2.44900000e+03,  2.44825000e+03,
#           2.44825000e+03, -9.88361510e-01, -1.52123386e-01,
#           0.00000000e+00],
#         [ 2.44850000e+03,  2.44900000e+03,  2.44825000e+03,
#           2.44900000e+03, -9.91444861e-01, -1.30526192e-01,
#           0.00000000e+00],
#         [ 2.44900000e+03,  2.44900000e+03,  2.44850000e+03,
#           2.44875000e+03, -9.94056338e-01, -1.08866875e-01,
#           0.00000000e+00],
#         [ 2.44850000e+03,  2.44950000e+03,  2.44850000e+03,
#           2.44875000e+03, -9.96194698e-01, -8.71557427e-02,
#           0.00000000e+00],
#         [ 2.44875000e+03,  2.44925000e+03,  2.44800000e+03,
#           2.44800000e+03, -9.97858923e-01, -6.54031292e-02,
#           0.00000000e+00],
#         [ 2.44800000e+03,  2.44850000e+03,  2.44800000e+03,
#           2.44850000e+03, -9.99048222e-01, -4.36193874e-02,
#           0.00000000e+00],
#         [ 2.44850000e+03,  2.44875000e+03,  2.44800000e+03,
#           2.44800000e+03, -9.99762027e-01, -2.18148850e-02,
#           0.00000000e+00],
#         [ 2.44800000e+03,  2.44825000e+03,  2.44750000e+03,
#           2.44800000e+03, -1.00000000e+00, -1.83697020e-16,
#           0.00000000e+00],
#         [ 2.44825000e+03,  2.44875000e+03,  2.44800000e+03,
#           2.44800000e+03, -9.99762027e-01,  2.18148850e-02,
#           0.00000000e+00],
#         [ 2.44800000e+03,  2.44825000e+03,  2.44750000e+03,
#           2.44800000e+03, -9.99048222e-01,  4.36193874e-02,
#           0.00000000e+00],
#         [ 2.44800000e+03,  2.44825000e+03,  2.44750000e+03,
#           2.44800000e+03, -9.97858923e-01,  6.54031292e-02,
#           0.00000000e+00],
#         [ 2.44800000e+03,  2.45000000e+03,  2.44775000e+03,
#           2.45000000e+03, -9.96194698e-01,  8.71557427e-02,
#           0.00000000e+00],
#         [ 2.45000000e+03,  2.45075000e+03,  2.44975000e+03,
#           2.45025000e+03, -9.94056338e-01,  1.08866875e-01,
#           0.00000000e+00],
#         [ 2.45050000e+03,  2.45150000e+03,  2.45000000e+03,
#           2.45100000e+03, -9.91444861e-01,  1.30526192e-01,
#           0.00000000e+00],
#         [ 2.45100000e+03,  2.45250000e+03,  2.45100000e+03,
#           2.45200000e+03, -9.88361510e-01,  1.52123386e-01,
#           0.00000000e+00],
#         [ 2.45225000e+03,  2.45250000e+03,  2.45175000e+03,
#           2.45200000e+03, -9.84807753e-01,  1.73648178e-01,
#           0.00000000e+00],
#         [ 2.45200000e+03,  2.45250000e+03,  2.45100000e+03,
#           2.45175000e+03, -9.80785280e-01,  1.95090322e-01,
#           0.00000000e+00],
#         [ 2.45175000e+03,  2.45200000e+03,  2.45075000e+03,
#           2.45100000e+03, -9.76296007e-01,  2.16439614e-01,
#           0.00000000e+00],
#         [ 2.45100000e+03,  2.45175000e+03,  2.45050000e+03,
#           2.45150000e+03, -9.71342070e-01,  2.37685892e-01,
#           0.00000000e+00],
#         [ 2.45175000e+03,  2.45200000e+03,  2.45100000e+03,
#           2.45175000e+03, -9.65925826e-01,  2.58819045e-01,
#           0.00000000e+00],
#         [ 2.45150000e+03,  2.45200000e+03,  2.45100000e+03,
#           2.45175000e+03, -9.60049854e-01,  2.79829014e-01,
#           0.00000000e+00],
#         [ 2.45150000e+03,  2.45200000e+03,  2.45100000e+03,
#           2.45200000e+03, -9.53716951e-01,  3.00705800e-01,
#           0.00000000e+00],
#         [ 2.45200000e+03,  2.45275000e+03,  2.45175000e+03,
#           2.45225000e+03, -9.46930129e-01,  3.21439465e-01,
#           0.00000000e+00],
#         [ 2.45250000e+03,  2.45300000e+03,  2.45200000e+03,
#           2.45225000e+03, -9.39692621e-01,  3.42020143e-01,
#           0.00000000e+00],
#         [ 2.45250000e+03,  2.45300000e+03,  2.45175000e+03,
#           2.45175000e+03, -9.32007869e-01,  3.62438038e-01,
#           0.00000000e+00],
#         [ 2.45175000e+03,  2.45250000e+03,  2.45150000e+03,
#           2.45200000e+03, -9.23879533e-01,  3.82683432e-01,
#           0.00000000e+00],
#         [ 2.45200000e+03,  2.45275000e+03,  2.45175000e+03,
#           2.45175000e+03, -9.15311479e-01,  4.02746690e-01,
#           0.00000000e+00],
#         [ 2.45175000e+03,  2.45300000e+03,  2.45175000e+03,
#           2.45225000e+03, -9.06307787e-01,  4.22618262e-01,
#           0.00000000e+00],
#         [ 2.45225000e+03,  2.45400000e+03,  2.45200000e+03,
#           2.45350000e+03, -8.96872742e-01,  4.42288690e-01,
#           0.00000000e+00],
#         [ 2.45350000e+03,  2.45500000e+03,  2.45325000e+03,
#           2.45425000e+03, -8.87010833e-01,  4.61748613e-01,
#           0.00000000e+00],
#         [ 2.45400000e+03,  2.45450000e+03,  2.45275000e+03,
#           2.45350000e+03, -8.76726756e-01,  4.80988769e-01,
#           0.00000000e+00],
#         [ 2.45325000e+03,  2.45375000e+03,  2.45125000e+03,
#           2.45225000e+03, -8.66025404e-01,  5.00000000e-01,
#           0.00000000e+00],
#         [ 2.45225000e+03,  2.45275000e+03,  2.45100000e+03,
#           2.45200000e+03, -8.54911871e-01,  5.18773258e-01,
#           0.00000000e+00],
#         [ 2.45200000e+03,  2.45200000e+03,  2.45100000e+03,
#           2.45125000e+03, -8.43391446e-01,  5.37299608e-01,
#           0.00000000e+00],
#         [ 2.45100000e+03,  2.45425000e+03,  2.45100000e+03,
#           2.45425000e+03, -8.31469612e-01,  5.55570233e-01,
#           0.00000000e+00],
#         [ 2.44150000e+03,  2.44400000e+03,  2.43975000e+03,
#           2.44200000e+03, -4.02746690e-01, -9.15311479e-01,
#           0.00000000e+00],
#         [ 2.44225000e+03,  2.44500000e+03,  2.44150000e+03,
#           2.44475000e+03, -4.22618262e-01, -9.06307787e-01,
#           0.00000000e+00],
#         [ 2.44475000e+03,  2.44500000e+03,  2.44250000e+03,
#           2.44350000e+03, -4.42288690e-01, -8.96872742e-01,
#           0.00000000e+00],
#         [ 2.44350000e+03,  2.44575000e+03,  2.44325000e+03,
#           2.44500000e+03, -4.61748613e-01, -8.87010833e-01,
#           0.00000000e+00],
#         [ 2.44500000e+03,  2.44575000e+03,  2.44350000e+03,
#           2.44525000e+03, -4.80988769e-01, -8.76726756e-01,
#           0.00000000e+00],
#         [ 2.44525000e+03,  2.44675000e+03,  2.44500000e+03,
#           2.44625000e+03, -5.00000000e-01, -8.66025404e-01,
#           0.00000000e+00],
#         [ 2.44600000e+03,  2.44600000e+03,  2.44400000e+03,
#           2.44500000e+03, -5.18773258e-01, -8.54911871e-01,
#           0.00000000e+00],
#         [ 2.44500000e+03,  2.44625000e+03,  2.44225000e+03,
#           2.44300000e+03, -5.37299608e-01, -8.43391446e-01,
#           0.00000000e+00],
#         [ 2.44300000e+03,  2.44525000e+03,  2.44275000e+03,
#           2.44450000e+03, -5.55570233e-01, -8.31469612e-01,
#           0.00000000e+00],
#         [ 2.44475000e+03,  2.44725000e+03,  2.44450000e+03,
#           2.44625000e+03, -5.73576436e-01, -8.19152044e-01,
#           0.00000000e+00]]), 0, False, {})
