# %%
import sys
import os
from baselines import logger, bench
from baselines.common import set_global_seeds
from baselines.common.cmd_util import make_atari_env, atari_arg_parser
from baselines.common.atari_wrappers import wrap_deepmind, make_atari
from baselines.common.vec_env.vec_frame_stack import VecFrameStack
from baselines.common.vec_env.dummy_vec_env import DummyVecEnv
from baselines.common.vec_env.subproc_vec_env import SubprocVecEnv
from baselines.common.vec_env.vec_normalize import VecNormalize, VecNormalizeTest
from baselines.ppo2 import ppo2
#from baselines.ppo2.policies import CnnPolicy, LstmPolicy, LnLstmPolicy, MlpPolicy
import multiprocessing
import tensorflow as tf
import pandas as pd
import numpy as np
import gym

from src.common.environments import ESTradingEnv

import matplotlib as mpl
# %matplotlib
# Out:
# /home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using matplotlib backend: Qt5Agg
# /home/ubuntu/src/anaconda3/envs/tensorflow/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: The finance module has been deprecated in mpl 2.0 and will be removed in mpl 2.2. Please use the module mpl_finance instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
#Register trading environment with OpenAI Gym
from gym.envs.registration import register
register(id='tradingenv-v0',
         entry_point='src.common.environments:ESTradingEnv_v2',)

# %%
from baselines.a2c.utils import fc, conv_to_fc, lstm, batch_to_seq, seq_to_batch
from baselines.common.distributions import make_pdtype
from baselines.common.input import observation_input

def ortho_init(scale=1.0):
    def _ortho_init(shape, dtype, partition_info=None):
        #lasagne ortho init for tf
        shape = tuple(shape)
        if len(shape) == 2:
            flat_shape = shape
        elif len(shape) > 2: # assumes NHWC
            flat_shape = (np.prod(shape[:-1]), shape[-1])
        else:
            raise NotImplementedError
        a = np.random.normal(0.0, 1.0, flat_shape)
        u, _, v = np.linalg.svd(a, full_matrices=False)
        q = u if u.shape == flat_shape else v # pick the one with the correct shape
        q = q.reshape(shape)
        return (scale * q[:shape[0], :shape[1]]).astype(np.float32)
    return _ortho_init

def conv(x, scope, *, nf, rf, stride, pad='VALID', init_scale=1.0, one_dim_bias=False):    
    channel_ax = 2
    strides = [1, stride, 1]
    bshape = [1, 1, nf]
    
    nin = x.get_shape()[channel_ax].value
    wshape = [rf, nin, nf]
    with tf.variable_scope(scope):
        w = tf.get_variable("w", wshape, initializer=ortho_init(init_scale))
        b = tf.get_variable("b", bshape, initializer=tf.constant_initializer(0.0))
        return b + tf.nn.conv1d(x, w, stride=stride, padding=pad)


def cnn(X, is_training, **conv_kwargs):
    activ = tf.nn.relu
    h = activ(conv(X, 'c1', nf=16, rf=4, stride=1, init_scale=np.sqrt(2),
                   **conv_kwargs))
    #h = tf.layers.dropout(h, rate=0.5, training=is_training)
    h2 = activ(conv(h, 'c2', nf=8, rf=4, stride=1, init_scale=np.sqrt(2), **conv_kwargs))
    #h2 = tf.layers.dropout(h2, rate=0.5, training=is_training)
    h3 = conv_to_fc(h2)
    return activ(fc(h3, 'fc1', nh=64, init_scale=np.sqrt(2)))


class CnnPolicy(object):

    def __init__(self, sess, ob_space, ac_space, nbatch, nsteps, reuse=False, **conv_kwargs): #pylint: disable=W0613
        if nsteps == 1:
            self._is_training = False
        else:
            self._is_training = True
            
        self.pdtype = make_pdtype(ac_space)
        X, processed_x = observation_input(ob_space, nbatch)
        with tf.variable_scope("model", reuse=reuse):
            h = cnn(processed_x, self._is_training, **conv_kwargs)
            #activ = tf.nn.relu
            #print(processed_x.get_shape())
            #h = activ(fc(processed_x, 'fc1', nh=512, init_scale=np.sqrt(2)))
            vf = fc(h, 'v', 1)[:,0]
            self.pd, self.pi = self.pdtype.pdfromlatent(h, init_scale=0.01)

        a0 = self.pd.sample()
        neglogp0 = self.pd.neglogp(a0)
        self.initial_state = None

        def step(ob, *_args, **_kwargs):
            a, v, neglogp = sess.run([a0, vf, neglogp0], {X:ob})
            return a, v, self.initial_state, neglogp

        def value(ob, *_args, **_kwargs):
            return sess.run(vf, {X:ob})

        self.X = X
        self.vf = vf
        self.step = step
        self.value = value
        
class LstmPolicy(object):

    def __init__(self, sess, ob_space, ac_space, nbatch, nsteps, nlstm=32, reuse=False):
        if nsteps == 1:
            self._is_training = False
        else:
            self._is_training = True
            
        nenv = nbatch // nsteps
        self.pdtype = make_pdtype(ac_space)
        X, processed_x = observation_input(ob_space, nbatch)

        M = tf.placeholder(tf.float32, [nbatch]) #mask (done t-1)
        S = tf.placeholder(tf.float32, [nenv, nlstm*2]) #states
        with tf.variable_scope("model", reuse=reuse):
            h = cnn(X, self._is_training)
            #h = processed_x
            #h = tf.layers.dropout(h, rate=0.5, training=self._is_training)
            xs = batch_to_seq(h, nenv, nsteps)
            ms = batch_to_seq(M, nenv, nsteps)
            h5, snew = lstm(xs, ms, S, 'lstm1', nh=nlstm)
            #h5 = tf.layers.dropout(h5, rate=0.5, training=self._is_training)
            h5 = seq_to_batch(h5)
            vf = fc(h5, 'v', 1)
            self.pd, self.pi = self.pdtype.pdfromlatent(h5)

        v0 = vf[:, 0]
        a0 = self.pd.sample()
        neglogp0 = self.pd.neglogp(a0)
        self.initial_state = np.zeros((nenv, nlstm*2), dtype=np.float32)

        def step(ob, state, mask):
            a, v, s, neglogp = sess.run([a0, v0, snew, neglogp0], {X:ob, S:state, M:mask})
            return a, v, s, neglogp

        def value(ob, state, mask):
            return sess.run(v0, {X:ob, S:state, M:mask})

        self.X = X
        self.M = M
        self.S = S
        self.vf = vf
        self.step = step
        self.value = value

# %%
def train(env_id, num_timesteps, seed, policy):

    ncpu = multiprocessing.cpu_count()
    if sys.platform == 'darwin': ncpu //= 2
    config = tf.ConfigProto(allow_soft_placement=True,
                            intra_op_parallelism_threads=ncpu,
                            inter_op_parallelism_threads=ncpu)
    config.gpu_options.allow_growth = True #pylint: disable=E1101
    tf.Session(config=config).__enter__()
    
    def make_env(rank):
        def _thunk():
            env = gym.make(env_id)
            env.seed(seed + rank)
            env = bench.Monitor(env, logger.get_dir() and os.path.join(logger.get_dir(), str(rank)))
            return env
        return _thunk
    

    #env = DummyVecEnv([make_env])
    env = SubprocVecEnv([make_env(i) for i in range(32)])
    env = VecNormalize(env, ob=True)
    set_global_seeds(seed)

    policy = LstmPolicy
    ppo2.learn(policy=policy, env=env, nsteps=256, nminibatches=32,
        lam=0.95, gamma=0.99, noptepochs=20, log_interval=1,
        ent_coef=.01,
        lr=lambda f: f * 2.5e-3,
        cliprange=0.1,
        total_timesteps=num_timesteps)

# %%
logger.configure()

train('tradingenv-v0', num_timesteps=1e7, seed=0, policy='cnn')
# Out:
# Logging to /tmp/openai-2018-08-23-09-38-32-256117
# WARNING:tensorflow:From /home/ubuntu/repos/baselines/baselines/common/distributions.py:148: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# WARNING:tensorflow:From /home/ubuntu/repos/baselines/baselines/common/distributions.py:159: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/ubuntu/repos/baselines/baselines/common/distributions.py:161: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# -------------------------------------
# | approxkl           | 0.011441799  |
# | clipfrac           | 0.4671448    |
# | eplenmean          | 111          |
# | eprewmean          | -7.79e+03    |
# | explained_variance | 0.0407       |
# | fps                | 95           |
# | nupdates           | 1            |
# | policy_entropy     | 1.0606921    |
# | policy_loss        | -0.029196804 |
# | serial_timesteps   | 256          |
# | time_elapsed       | 86           |
# | total_timesteps    | 8192         |
# | value_loss         | 0.4977464    |
# -------------------------------------
# Saving to /tmp/openai-2018-08-23-09-38-32-256117/checkpoints/00001
# ------------------------------------
# | approxkl           | 0.03218992  |
# | clipfrac           | 0.7348999   |
# | eplenmean          | 126         |
# | eprewmean          | -8.5e+03    |
# | explained_variance | 0.101       |
# | fps                | 117         |
# | nupdates           | 2           |
# | policy_entropy     | 1.0256684   |
# | policy_loss        | -0.05861097 |
# | serial_timesteps   | 512         |
# | time_elapsed       | 156         |
# | total_timesteps    | 16384       |
# | value_loss         | 0.06255902  |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.047077723 |
# | clipfrac           | 0.7973877   |
# | eplenmean          | 154         |
# | eprewmean          | -1.19e+04   |
# | explained_variance | 0.0932      |
# | fps                | 116         |
# | nupdates           | 3           |
# | policy_entropy     | 1.0065005   |
# | policy_loss        | -0.06116537 |
# | serial_timesteps   | 768         |
# | time_elapsed       | 226         |
# | total_timesteps    | 24576       |
# | value_loss         | 0.05265028  |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.060181    |
# | clipfrac           | 0.8204956   |
# | eplenmean          | 160         |
# | eprewmean          | -1.22e+04   |
# | explained_variance | 0.0581      |
# | fps                | 116         |
# | nupdates           | 4           |
# | policy_entropy     | 0.9772909   |
# | policy_loss        | -0.05776624 |
# | serial_timesteps   | 1024        |
# | time_elapsed       | 296         |
# | total_timesteps    | 32768       |
# | value_loss         | 0.041933678 |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.07711496   |
# | clipfrac           | 0.8272217    |
# | eplenmean          | 152          |
# | eprewmean          | -1.02e+04    |
# | explained_variance | 0.103        |
# | fps                | 117          |
# | nupdates           | 5            |
# | policy_entropy     | 0.95202285   |
# | policy_loss        | -0.058886003 |
# | serial_timesteps   | 1280         |
# | time_elapsed       | 366          |
# | total_timesteps    | 40960        |
# | value_loss         | 0.052726936  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.09431493   |
# | clipfrac           | 0.8370239    |
# | eplenmean          | 172          |
# | eprewmean          | -1.17e+04    |
# | explained_variance | 0.065        |
# | fps                | 116          |
# | nupdates           | 6            |
# | policy_entropy     | 0.91916335   |
# | policy_loss        | -0.059402473 |
# | serial_timesteps   | 1536         |
# | time_elapsed       | 437          |
# | total_timesteps    | 49152        |
# | value_loss         | 0.062024374  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.10892357   |
# | clipfrac           | 0.8291992    |
# | eplenmean          | 174          |
# | eprewmean          | -1.16e+04    |
# | explained_variance | 0.138        |
# | fps                | 115          |
# | nupdates           | 7            |
# | policy_entropy     | 0.8891309    |
# | policy_loss        | -0.055404417 |
# | serial_timesteps   | 1792         |
# | time_elapsed       | 508          |
# | total_timesteps    | 57344        |
# | value_loss         | 0.07491598   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.11165086   |
# | clipfrac           | 0.81725466   |
# | eplenmean          | 163          |
# | eprewmean          | -1.05e+04    |
# | explained_variance | 0.157        |
# | fps                | 117          |
# | nupdates           | 8            |
# | policy_entropy     | 0.8685586    |
# | policy_loss        | -0.056858677 |
# | serial_timesteps   | 2048         |
# | time_elapsed       | 577          |
# | total_timesteps    | 65536        |
# | value_loss         | 0.059065126  |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.14170828  |
# | clipfrac           | 0.8120483   |
# | eplenmean          | 167         |
# | eprewmean          | -1.05e+04   |
# | explained_variance | 0.166       |
# | fps                | 116         |
# | nupdates           | 9           |
# | policy_entropy     | 0.8371099   |
# | policy_loss        | -0.05308962 |
# | serial_timesteps   | 2304        |
# | time_elapsed       | 648         |
# | total_timesteps    | 73728       |
# | value_loss         | 0.06512304  |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.1615479    |
# | clipfrac           | 0.7942444    |
# | eplenmean          | 169          |
# | eprewmean          | -9.7e+03     |
# | explained_variance | 0.198        |
# | fps                | 116          |
# | nupdates           | 10           |
# | policy_entropy     | 0.81177723   |
# | policy_loss        | -0.050762463 |
# | serial_timesteps   | 2560         |
# | time_elapsed       | 718          |
# | total_timesteps    | 81920        |
# | value_loss         | 0.052196093  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.17538865   |
# | clipfrac           | 0.78070676   |
# | eplenmean          | 183          |
# | eprewmean          | -1.04e+04    |
# | explained_variance | 0.139        |
# | fps                | 116          |
# | nupdates           | 11           |
# | policy_entropy     | 0.7835089    |
# | policy_loss        | -0.048655745 |
# | serial_timesteps   | 2816         |
# | time_elapsed       | 788          |
# | total_timesteps    | 90112        |
# | value_loss         | 0.05782906   |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.18936868  |
# | clipfrac           | 0.7737793   |
# | eplenmean          | 172         |
# | eprewmean          | -8.75e+03   |
# | explained_variance | 0.107       |
# | fps                | 116         |
# | nupdates           | 12          |
# | policy_entropy     | 0.75506216  |
# | policy_loss        | -0.05047918 |
# | serial_timesteps   | 3072        |
# | time_elapsed       | 858         |
# | total_timesteps    | 98304       |
# | value_loss         | 0.04885318  |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.20340244  |
# | clipfrac           | 0.7612549   |
# | eplenmean          | 160         |
# | eprewmean          | -7.39e+03   |
# | explained_variance | 0.0647      |
# | fps                | 117         |
# | nupdates           | 13          |
# | policy_entropy     | 0.7240921   |
# | policy_loss        | -0.04882177 |
# | serial_timesteps   | 3328        |
# | time_elapsed       | 928         |
# | total_timesteps    | 106496      |
# | value_loss         | 0.04900317  |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.23909214  |
# | clipfrac           | 0.73638916  |
# | eplenmean          | 174         |
# | eprewmean          | -7.61e+03   |
# | explained_variance | 0.00378     |
# | fps                | 116         |
# | nupdates           | 14          |
# | policy_entropy     | 0.70232886  |
# | policy_loss        | -0.04372043 |
# | serial_timesteps   | 3584        |
# | time_elapsed       | 998         |
# | total_timesteps    | 114688      |
# | value_loss         | 0.0414134   |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.25558668  |
# | clipfrac           | 0.7400757   |
# | eplenmean          | 182         |
# | eprewmean          | -7.43e+03   |
# | explained_variance | 0.0842      |
# | fps                | 117         |
# | nupdates           | 15          |
# | policy_entropy     | 0.6939071   |
# | policy_loss        | -0.04488061 |
# | serial_timesteps   | 3840        |
# | time_elapsed       | 1.07e+03    |
# | total_timesteps    | 122880      |
# | value_loss         | 0.038627606 |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.23214145  |
# | clipfrac           | 0.7169922   |
# | eplenmean          | 178         |
# | eprewmean          | -6.8e+03    |
# | explained_variance | 0.131       |
# | fps                | 117         |
# | nupdates           | 16          |
# | policy_entropy     | 0.6646603   |
# | policy_loss        | -0.04252208 |
# | serial_timesteps   | 4096        |
# | time_elapsed       | 1.14e+03    |
# | total_timesteps    | 131072      |
# | value_loss         | 0.03133208  |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.2335445   |
# | clipfrac           | 0.7039673   |
# | eplenmean          | 183         |
# | eprewmean          | -6.46e+03   |
# | explained_variance | 0.0394      |
# | fps                | 116         |
# | nupdates           | 17          |
# | policy_entropy     | 0.642306    |
# | policy_loss        | -0.04247155 |
# | serial_timesteps   | 4352        |
# | time_elapsed       | 1.21e+03    |
# | total_timesteps    | 139264      |
# | value_loss         | 0.036975484 |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.2898392    |
# | clipfrac           | 0.71781003   |
# | eplenmean          | 185          |
# | eprewmean          | -5.76e+03    |
# | explained_variance | 0.0556       |
# | fps                | 113          |
# | nupdates           | 18           |
# | policy_entropy     | 0.65066606   |
# | policy_loss        | -0.041419953 |
# | serial_timesteps   | 4608         |
# | time_elapsed       | 1.28e+03     |
# | total_timesteps    | 147456       |
# | value_loss         | 0.027711371  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.2735398    |
# | clipfrac           | 0.69518435   |
# | eplenmean          | 173          |
# | eprewmean          | -5.05e+03    |
# | explained_variance | 0.0757       |
# | fps                | 116          |
# | nupdates           | 19           |
# | policy_entropy     | 0.6348424    |
# | policy_loss        | -0.039174758 |
# | serial_timesteps   | 4864         |
# | time_elapsed       | 1.35e+03     |
# | total_timesteps    | 155648       |
# | value_loss         | 0.033375863  |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.2712073   |
# | clipfrac           | 0.69967043  |
# | eplenmean          | 165         |
# | eprewmean          | -4.71e+03   |
# | explained_variance | 0.0508      |
# | fps                | 116         |
# | nupdates           | 20          |
# | policy_entropy     | 0.64947796  |
# | policy_loss        | -0.04239839 |
# | serial_timesteps   | 5120        |
# | time_elapsed       | 1.42e+03    |
# | total_timesteps    | 163840      |
# | value_loss         | 0.02670249  |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.25724828   |
# | clipfrac           | 0.6760925    |
# | eplenmean          | 164          |
# | eprewmean          | -4.58e+03    |
# | explained_variance | 0.045        |
# | fps                | 116          |
# | nupdates           | 21           |
# | policy_entropy     | 0.6123648    |
# | policy_loss        | -0.040171474 |
# | serial_timesteps   | 5376         |
# | time_elapsed       | 1.49e+03     |
# | total_timesteps    | 172032       |
# | value_loss         | 0.02825202   |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.28600684  |
# | clipfrac           | 0.668573    |
# | eplenmean          | 176         |
# | eprewmean          | -4.5e+03    |
# | explained_variance | 0.0122      |
# | fps                | 117         |
# | nupdates           | 22          |
# | policy_entropy     | 0.5998072   |
# | policy_loss        | -0.03947739 |
# | serial_timesteps   | 5632        |
# | time_elapsed       | 1.56e+03    |
# | total_timesteps    | 180224      |
# | value_loss         | 0.022560949 |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.30231255   |
# | clipfrac           | 0.6503967    |
# | eplenmean          | 192          |
# | eprewmean          | -5.36e+03    |
# | explained_variance | -0.0205      |
# | fps                | 117          |
# | nupdates           | 23           |
# | policy_entropy     | 0.56565607   |
# | policy_loss        | -0.040459324 |
# | serial_timesteps   | 5888         |
# | time_elapsed       | 1.63e+03     |
# | total_timesteps    | 188416       |
# | value_loss         | 0.021790285  |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.32236314  |
# | clipfrac           | 0.61903685  |
# | eplenmean          | 192         |
# | eprewmean          | -4.84e+03   |
# | explained_variance | -0.00488    |
# | fps                | 117         |
# | nupdates           | 24          |
# | policy_entropy     | 0.54080355  |
# | policy_loss        | -0.03560805 |
# | serial_timesteps   | 6144        |
# | time_elapsed       | 1.7e+03     |
# | total_timesteps    | 196608      |
# | value_loss         | 0.015485577 |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.29838043  |
# | clipfrac           | 0.61269534  |
# | eplenmean          | 199         |
# | eprewmean          | -4.17e+03   |
# | explained_variance | 0.00204     |
# | fps                | 117         |
# | nupdates           | 25          |
# | policy_entropy     | 0.54809487  |
# | policy_loss        | -0.03549976 |
# | serial_timesteps   | 6400        |
# | time_elapsed       | 1.77e+03    |
# | total_timesteps    | 204800      |
# | value_loss         | 0.016241632 |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.29541564  |
# | clipfrac           | 0.6126038   |
# | eplenmean          | 198         |
# | eprewmean          | -3.7e+03    |
# | explained_variance | 0.0135      |
# | fps                | 117         |
# | nupdates           | 26          |
# | policy_entropy     | 0.5395068   |
# | policy_loss        | -0.03561136 |
# | serial_timesteps   | 6656        |
# | time_elapsed       | 1.84e+03    |
# | total_timesteps    | 212992      |
# | value_loss         | 0.016997851 |
# ------------------------------------
# ------------------------------------
# | approxkl           | 0.32591724  |
# | clipfrac           | 0.5761658   |
# | eplenmean          | 180         |
# | eprewmean          | -3.47e+03   |
# | explained_variance | 0.000511    |
# | fps                | 116         |
# | nupdates           | 27          |
# | policy_entropy     | 0.5001319   |
# | policy_loss        | -0.03443608 |
# | serial_timesteps   | 6912        |
# | time_elapsed       | 1.91e+03    |
# | total_timesteps    | 221184      |
# | value_loss         | 0.014226097 |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.36925277   |
# | clipfrac           | 0.56807864   |
# | eplenmean          | 186          |
# | eprewmean          | -3.42e+03    |
# | explained_variance | 0.00467      |
# | fps                | 116          |
# | nupdates           | 28           |
# | policy_entropy     | 0.49113822   |
# | policy_loss        | -0.028315928 |
# | serial_timesteps   | 7168         |
# | time_elapsed       | 1.98e+03     |
# | total_timesteps    | 229376       |
# | value_loss         | 0.009912683  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.37088498   |
# | clipfrac           | 0.5581726    |
# | eplenmean          | 222          |
# | eprewmean          | -3.62e+03    |
# | explained_variance | -0.00105     |
# | fps                | 115          |
# | nupdates           | 29           |
# | policy_entropy     | 0.48334938   |
# | policy_loss        | -0.027583372 |
# | serial_timesteps   | 7424         |
# | time_elapsed       | 2.05e+03     |
# | total_timesteps    | 237568       |
# | value_loss         | 0.008417767  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.3326018    |
# | clipfrac           | 0.5780029    |
# | eplenmean          | 224          |
# | eprewmean          | -3.25e+03    |
# | explained_variance | 0.0267       |
# | fps                | 114          |
# | nupdates           | 30           |
# | policy_entropy     | 0.50313294   |
# | policy_loss        | -0.028612971 |
# | serial_timesteps   | 7680         |
# | time_elapsed       | 2.12e+03     |
# | total_timesteps    | 245760       |
# | value_loss         | 0.0072004    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.32002914   |
# | clipfrac           | 0.5618469    |
# | eplenmean          | 213          |
# | eprewmean          | -2.85e+03    |
# | explained_variance | -0.0255      |
# | fps                | 115          |
# | nupdates           | 31           |
# | policy_entropy     | 0.48881626   |
# | policy_loss        | -0.029117873 |
# | serial_timesteps   | 7936         |
# | time_elapsed       | 2.19e+03     |
# | total_timesteps    | 253952       |
# | value_loss         | 0.0065859007 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.3043658    |
# | clipfrac           | 0.5519226    |
# | eplenmean          | 205          |
# | eprewmean          | -2.62e+03    |
# | explained_variance | -0.00743     |
# | fps                | 114          |
# | nupdates           | 32           |
# | policy_entropy     | 0.4876027    |
# | policy_loss        | -0.027914966 |
# | serial_timesteps   | 8192         |
# | time_elapsed       | 2.26e+03     |
# | total_timesteps    | 262144       |
# | value_loss         | 0.0059232553 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.32371238   |
# | clipfrac           | 0.5331055    |
# | eplenmean          | 216          |
# | eprewmean          | -2.66e+03    |
# | explained_variance | -0.00722     |
# | fps                | 115          |
# | nupdates           | 33           |
# | policy_entropy     | 0.4576467    |
# | policy_loss        | -0.027853722 |
# | serial_timesteps   | 8448         |
# | time_elapsed       | 2.34e+03     |
# | total_timesteps    | 270336       |
# | value_loss         | 0.0052874004 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.34841067   |
# | clipfrac           | 0.5447998    |
# | eplenmean          | 213          |
# | eprewmean          | -2.33e+03    |
# | explained_variance | -0.00565     |
# | fps                | 114          |
# | nupdates           | 34           |
# | policy_entropy     | 0.47246033   |
# | policy_loss        | -0.026763106 |
# | serial_timesteps   | 8704         |
# | time_elapsed       | 2.41e+03     |
# | total_timesteps    | 278528       |
# | value_loss         | 0.004554359  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.31984562   |
# | clipfrac           | 0.5465271    |
# | eplenmean          | 205          |
# | eprewmean          | -2.12e+03    |
# | explained_variance | -0.0185      |
# | fps                | 115          |
# | nupdates           | 35           |
# | policy_entropy     | 0.46212918   |
# | policy_loss        | -0.029116254 |
# | serial_timesteps   | 8960         |
# | time_elapsed       | 2.48e+03     |
# | total_timesteps    | 286720       |
# | value_loss         | 0.0045687365 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.34745076   |
# | clipfrac           | 0.51315916   |
# | eplenmean          | 196          |
# | eprewmean          | -1.86e+03    |
# | explained_variance | -0.00157     |
# | fps                | 116          |
# | nupdates           | 36           |
# | policy_entropy     | 0.42317432   |
# | policy_loss        | -0.026833406 |
# | serial_timesteps   | 9216         |
# | time_elapsed       | 2.55e+03     |
# | total_timesteps    | 294912       |
# | value_loss         | 0.002487487  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.36150596   |
# | clipfrac           | 0.5286865    |
# | eplenmean          | 221          |
# | eprewmean          | -1.88e+03    |
# | explained_variance | -0.017       |
# | fps                | 116          |
# | nupdates           | 37           |
# | policy_entropy     | 0.43294802   |
# | policy_loss        | -0.023247061 |
# | serial_timesteps   | 9472         |
# | time_elapsed       | 2.62e+03     |
# | total_timesteps    | 303104       |
# | value_loss         | 0.0022203657 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.3473076    |
# | clipfrac           | 0.5250305    |
# | eplenmean          | 226          |
# | eprewmean          | -1.57e+03    |
# | explained_variance | -0.0159      |
# | fps                | 114          |
# | nupdates           | 38           |
# | policy_entropy     | 0.4384634    |
# | policy_loss        | -0.02072258  |
# | serial_timesteps   | 9728         |
# | time_elapsed       | 2.69e+03     |
# | total_timesteps    | 311296       |
# | value_loss         | 0.0018248118 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.3372022    |
# | clipfrac           | 0.52212524   |
# | eplenmean          | 214          |
# | eprewmean          | -1.31e+03    |
# | explained_variance | -0.0136      |
# | fps                | 116          |
# | nupdates           | 39           |
# | policy_entropy     | 0.4300905    |
# | policy_loss        | -0.021632573 |
# | serial_timesteps   | 9984         |
# | time_elapsed       | 2.76e+03     |
# | total_timesteps    | 319488       |
# | value_loss         | 0.0018808076 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.35266834   |
# | clipfrac           | 0.52356565   |
# | eplenmean          | 203          |
# | eprewmean          | -1.21e+03    |
# | explained_variance | -0.00389     |
# | fps                | 113          |
# | nupdates           | 40           |
# | policy_entropy     | 0.42201352   |
# | policy_loss        | -0.022177657 |
# | serial_timesteps   | 10240        |
# | time_elapsed       | 2.83e+03     |
# | total_timesteps    | 327680       |
# | value_loss         | 0.003506977  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.35405686   |
# | clipfrac           | 0.5136902    |
# | eplenmean          | 204          |
# | eprewmean          | -1.36e+03    |
# | explained_variance | -0.0182      |
# | fps                | 113          |
# | nupdates           | 41           |
# | policy_entropy     | 0.42580757   |
# | policy_loss        | -0.021007642 |
# | serial_timesteps   | 10496        |
# | time_elapsed       | 2.9e+03      |
# | total_timesteps    | 335872       |
# | value_loss         | 0.0016858712 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.322645     |
# | clipfrac           | 0.5173279    |
# | eplenmean          | 188          |
# | eprewmean          | -1.32e+03    |
# | explained_variance | -0.0103      |
# | fps                | 114          |
# | nupdates           | 42           |
# | policy_entropy     | 0.4225611    |
# | policy_loss        | -0.024244785 |
# | serial_timesteps   | 10752        |
# | time_elapsed       | 2.98e+03     |
# | total_timesteps    | 344064       |
# | value_loss         | 0.0016054863 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.33658814   |
# | clipfrac           | 0.50549316   |
# | eplenmean          | 193          |
# | eprewmean          | -1.28e+03    |
# | explained_variance | -0.0227      |
# | fps                | 115          |
# | nupdates           | 43           |
# | policy_entropy     | 0.412963     |
# | policy_loss        | -0.023078773 |
# | serial_timesteps   | 11008        |
# | time_elapsed       | 3.05e+03     |
# | total_timesteps    | 352256       |
# | value_loss         | 0.001350308  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.33654916   |
# | clipfrac           | 0.5216858    |
# | eplenmean          | 191          |
# | eprewmean          | -1.07e+03    |
# | explained_variance | -0.0363      |
# | fps                | 114          |
# | nupdates           | 44           |
# | policy_entropy     | 0.4288748    |
# | policy_loss        | -0.021984074 |
# | serial_timesteps   | 11264        |
# | time_elapsed       | 3.12e+03     |
# | total_timesteps    | 360448       |
# | value_loss         | 0.0016876959 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.34646285   |
# | clipfrac           | 0.5214294    |
# | eplenmean          | 185          |
# | eprewmean          | -1.13e+03    |
# | explained_variance | -0.00877     |
# | fps                | 116          |
# | nupdates           | 45           |
# | policy_entropy     | 0.4236408    |
# | policy_loss        | -0.019619785 |
# | serial_timesteps   | 11520        |
# | time_elapsed       | 3.19e+03     |
# | total_timesteps    | 368640       |
# | value_loss         | 0.0017502211 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.35606414   |
# | clipfrac           | 0.5248535    |
# | eplenmean          | 180          |
# | eprewmean          | -1.02e+03    |
# | explained_variance | -0.00833     |
# | fps                | 113          |
# | nupdates           | 46           |
# | policy_entropy     | 0.42689657   |
# | policy_loss        | -0.022652892 |
# | serial_timesteps   | 11776        |
# | time_elapsed       | 3.26e+03     |
# | total_timesteps    | 376832       |
# | value_loss         | 0.0012448576 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.34571147    |
# | clipfrac           | 0.5275757     |
# | eplenmean          | 207           |
# | eprewmean          | -1.06e+03     |
# | explained_variance | -0.00817      |
# | fps                | 116           |
# | nupdates           | 47            |
# | policy_entropy     | 0.4299952     |
# | policy_loss        | -0.020027917  |
# | serial_timesteps   | 12032         |
# | time_elapsed       | 3.33e+03      |
# | total_timesteps    | 385024        |
# | value_loss         | 0.00090240175 |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.3633259    |
# | clipfrac           | 0.5293945    |
# | eplenmean          | 202          |
# | eprewmean          | -1.03e+03    |
# | explained_variance | -0.00954     |
# | fps                | 116          |
# | nupdates           | 48           |
# | policy_entropy     | 0.42130843   |
# | policy_loss        | -0.017518083 |
# | serial_timesteps   | 12288        |
# | time_elapsed       | 3.4e+03      |
# | total_timesteps    | 393216       |
# | value_loss         | 0.0015240158 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.36256143   |
# | clipfrac           | 0.5136353    |
# | eplenmean          | 174          |
# | eprewmean          | -931         |
# | explained_variance | -0.0248      |
# | fps                | 115          |
# | nupdates           | 49           |
# | policy_entropy     | 0.41731516   |
# | policy_loss        | -0.01677776  |
# | serial_timesteps   | 12544        |
# | time_elapsed       | 3.47e+03     |
# | total_timesteps    | 401408       |
# | value_loss         | 0.0009250534 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.31099337   |
# | clipfrac           | 0.4836731    |
# | eplenmean          | 191          |
# | eprewmean          | -939         |
# | explained_variance | -0.00538     |
# | fps                | 116          |
# | nupdates           | 50           |
# | policy_entropy     | 0.40716577   |
# | policy_loss        | -0.021352367 |
# | serial_timesteps   | 12800        |
# | time_elapsed       | 3.54e+03     |
# | total_timesteps    | 409600       |
# | value_loss         | 0.0007833    |
# -------------------------------------
# Saving to /tmp/openai-2018-08-23-09-38-32-256117/checkpoints/00050
# --------------------------------------
# | approxkl           | 0.36326292    |
# | clipfrac           | 0.5080078     |
# | eplenmean          | 214           |
# | eprewmean          | -862          |
# | explained_variance | -0.0183       |
# | fps                | 115           |
# | nupdates           | 51            |
# | policy_entropy     | 0.40913707    |
# | policy_loss        | -0.019550959  |
# | serial_timesteps   | 13056         |
# | time_elapsed       | 3.61e+03      |
# | total_timesteps    | 417792        |
# | value_loss         | 0.00063964777 |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.32354444   |
# | clipfrac           | 0.48966065   |
# | eplenmean          | 222          |
# | eprewmean          | -821         |
# | explained_variance | -0.00727     |
# | fps                | 117          |
# | nupdates           | 52           |
# | policy_entropy     | 0.39612657   |
# | policy_loss        | -0.019283075 |
# | serial_timesteps   | 13312        |
# | time_elapsed       | 3.68e+03     |
# | total_timesteps    | 425984       |
# | value_loss         | 0.0007984036 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.364521      |
# | clipfrac           | 0.49937135    |
# | eplenmean          | 217           |
# | eprewmean          | -822          |
# | explained_variance | -0.0164       |
# | fps                | 114           |
# | nupdates           | 53            |
# | policy_entropy     | 0.40423456    |
# | policy_loss        | -0.017466348  |
# | serial_timesteps   | 13568         |
# | time_elapsed       | 3.76e+03      |
# | total_timesteps    | 434176        |
# | value_loss         | 0.00078782236 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.3187671     |
# | clipfrac           | 0.5017212     |
# | eplenmean          | 191           |
# | eprewmean          | -753          |
# | explained_variance | -0.0302       |
# | fps                | 114           |
# | nupdates           | 54            |
# | policy_entropy     | 0.41503325    |
# | policy_loss        | -0.020790946  |
# | serial_timesteps   | 13824         |
# | time_elapsed       | 3.83e+03      |
# | total_timesteps    | 442368        |
# | value_loss         | 0.00053295906 |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.3139007    |
# | clipfrac           | 0.4988098    |
# | eplenmean          | 208          |
# | eprewmean          | -765         |
# | explained_variance | -0.00439     |
# | fps                | 115          |
# | nupdates           | 55           |
# | policy_entropy     | 0.41723424   |
# | policy_loss        | -0.017255764 |
# | serial_timesteps   | 14080        |
# | time_elapsed       | 3.9e+03      |
# | total_timesteps    | 450560       |
# | value_loss         | 0.00099473   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.288795      |
# | clipfrac           | 0.4781189     |
# | eplenmean          | 204           |
# | eprewmean          | -812          |
# | explained_variance | -0.00887      |
# | fps                | 114           |
# | nupdates           | 56            |
# | policy_entropy     | 0.40056172    |
# | policy_loss        | -0.01857903   |
# | serial_timesteps   | 14336         |
# | time_elapsed       | 3.97e+03      |
# | total_timesteps    | 458752        |
# | value_loss         | 0.00096653245 |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.33651516   |
# | clipfrac           | 0.5018738    |
# | eplenmean          | 213          |
# | eprewmean          | -844         |
# | explained_variance | -0.022       |
# | fps                | 113          |
# | nupdates           | 57           |
# | policy_entropy     | 0.42124215   |
# | policy_loss        | -0.015577619 |
# | serial_timesteps   | 14592        |
# | time_elapsed       | 4.04e+03     |
# | total_timesteps    | 466944       |
# | value_loss         | 0.0006038521 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.32434905   |
# | clipfrac           | 0.49111938   |
# | eplenmean          | 208          |
# | eprewmean          | -810         |
# | explained_variance | -0.0202      |
# | fps                | 114          |
# | nupdates           | 58           |
# | policy_entropy     | 0.4118898    |
# | policy_loss        | -0.019970108 |
# | serial_timesteps   | 14848        |
# | time_elapsed       | 4.11e+03     |
# | total_timesteps    | 475136       |
# | value_loss         | 0.0006075858 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.30827639    |
# | clipfrac           | 0.4874939     |
# | eplenmean          | 189           |
# | eprewmean          | -710          |
# | explained_variance | -0.0334       |
# | fps                | 113           |
# | nupdates           | 59            |
# | policy_entropy     | 0.41527873    |
# | policy_loss        | -0.01925296   |
# | serial_timesteps   | 15104         |
# | time_elapsed       | 4.19e+03      |
# | total_timesteps    | 483328        |
# | value_loss         | 0.00066393265 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.35026246    |
# | clipfrac           | 0.48726195    |
# | eplenmean          | 180           |
# | eprewmean          | -714          |
# | explained_variance | -0.00929      |
# | fps                | 114           |
# | nupdates           | 60            |
# | policy_entropy     | 0.40082288    |
# | policy_loss        | -0.01931334   |
# | serial_timesteps   | 15360         |
# | time_elapsed       | 4.26e+03      |
# | total_timesteps    | 491520        |
# | value_loss         | 0.00059723994 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.33219916    |
# | clipfrac           | 0.501709      |
# | eplenmean          | 188           |
# | eprewmean          | -727          |
# | explained_variance | -0.0215       |
# | fps                | 115           |
# | nupdates           | 61            |
# | policy_entropy     | 0.42118773    |
# | policy_loss        | -0.019566927  |
# | serial_timesteps   | 15616         |
# | time_elapsed       | 4.33e+03      |
# | total_timesteps    | 499712        |
# | value_loss         | 0.00078108633 |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.3176207    |
# | clipfrac           | 0.47392577   |
# | eplenmean          | 191          |
# | eprewmean          | -744         |
# | explained_variance | -0.0132      |
# | fps                | 117          |
# | nupdates           | 62           |
# | policy_entropy     | 0.39843398   |
# | policy_loss        | -0.01617001  |
# | serial_timesteps   | 15872        |
# | time_elapsed       | 4.4e+03      |
# | total_timesteps    | 507904       |
# | value_loss         | 0.0006837353 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.3179647     |
# | clipfrac           | 0.47924194    |
# | eplenmean          | 184           |
# | eprewmean          | -707          |
# | explained_variance | -0.0176       |
# | fps                | 117           |
# | nupdates           | 63            |
# | policy_entropy     | 0.40408963    |
# | policy_loss        | -0.015625302  |
# | serial_timesteps   | 16128         |
# | time_elapsed       | 4.47e+03      |
# | total_timesteps    | 516096        |
# | value_loss         | 0.00041854038 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.33726722    |
# | clipfrac           | 0.49330443    |
# | eplenmean          | 195           |
# | eprewmean          | -635          |
# | explained_variance | -0.0146       |
# | fps                | 118           |
# | nupdates           | 64            |
# | policy_entropy     | 0.40942377    |
# | policy_loss        | -0.014157971  |
# | serial_timesteps   | 16384         |
# | time_elapsed       | 4.54e+03      |
# | total_timesteps    | 524288        |
# | value_loss         | 0.00047155895 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.2948162     |
# | clipfrac           | 0.46138915    |
# | eplenmean          | 205           |
# | eprewmean          | -619          |
# | explained_variance | -0.0186       |
# | fps                | 118           |
# | nupdates           | 65            |
# | policy_entropy     | 0.3908754     |
# | policy_loss        | -0.017937198  |
# | serial_timesteps   | 16640         |
# | time_elapsed       | 4.61e+03      |
# | total_timesteps    | 532480        |
# | value_loss         | 0.00042684964 |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.3135765    |
# | clipfrac           | 0.47616577   |
# | eplenmean          | 214          |
# | eprewmean          | -618         |
# | explained_variance | -0.00998     |
# | fps                | 117          |
# | nupdates           | 66           |
# | policy_entropy     | 0.40420803   |
# | policy_loss        | -0.01287781  |
# | serial_timesteps   | 16896        |
# | time_elapsed       | 4.68e+03     |
# | total_timesteps    | 540672       |
# | value_loss         | 0.0003665842 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.31665888   |
# | clipfrac           | 0.4708252    |
# | eplenmean          | 227          |
# | eprewmean          | -620         |
# | explained_variance | -0.0199      |
# | fps                | 116          |
# | nupdates           | 67           |
# | policy_entropy     | 0.40740544   |
# | policy_loss        | -0.015682096 |
# | serial_timesteps   | 17152        |
# | time_elapsed       | 4.75e+03     |
# | total_timesteps    | 548864       |
# | value_loss         | 0.0004242538 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.31526324   |
# | clipfrac           | 0.4532776    |
# | eplenmean          | 202          |
# | eprewmean          | -633         |
# | explained_variance | -0.0133      |
# | fps                | 117          |
# | nupdates           | 68           |
# | policy_entropy     | 0.38575166   |
# | policy_loss        | -0.005864977 |
# | serial_timesteps   | 17408        |
# | time_elapsed       | 4.82e+03     |
# | total_timesteps    | 557056       |
# | value_loss         | 0.0005592611 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.3174641    |
# | clipfrac           | 0.46534425   |
# | eplenmean          | 210          |
# | eprewmean          | -668         |
# | explained_variance | -0.0141      |
# | fps                | 116          |
# | nupdates           | 69           |
# | policy_entropy     | 0.39877126   |
# | policy_loss        | -0.007664268 |
# | serial_timesteps   | 17664        |
# | time_elapsed       | 4.89e+03     |
# | total_timesteps    | 565248       |
# | value_loss         | 0.0005514395 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.30525178   |
# | clipfrac           | 0.44052735   |
# | eplenmean          | 218          |
# | eprewmean          | -683         |
# | explained_variance | -0.00748     |
# | fps                | 115          |
# | nupdates           | 70           |
# | policy_entropy     | 0.37206805   |
# | policy_loss        | -0.01251954  |
# | serial_timesteps   | 17920        |
# | time_elapsed       | 4.96e+03     |
# | total_timesteps    | 573440       |
# | value_loss         | 0.0005089691 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.31399822   |
# | clipfrac           | 0.45253295   |
# | eplenmean          | 243          |
# | eprewmean          | -718         |
# | explained_variance | -0.0102      |
# | fps                | 115          |
# | nupdates           | 71           |
# | policy_entropy     | 0.38028666   |
# | policy_loss        | -0.014458532 |
# | serial_timesteps   | 18176        |
# | time_elapsed       | 5.03e+03     |
# | total_timesteps    | 581632       |
# | value_loss         | 0.0006086768 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.3163043     |
# | clipfrac           | 0.46955568    |
# | eplenmean          | 243           |
# | eprewmean          | -718          |
# | explained_variance | -0.0457       |
# | fps                | 116           |
# | nupdates           | 72            |
# | policy_entropy     | 0.4058849     |
# | policy_loss        | -0.0069822585 |
# | serial_timesteps   | 18432         |
# | time_elapsed       | 5.1e+03       |
# | total_timesteps    | 589824        |
# | value_loss         | 0.00057382416 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.33085373    |
# | clipfrac           | 0.48291627    |
# | eplenmean          | 224           |
# | eprewmean          | -687          |
# | explained_variance | -0.000384     |
# | fps                | 115           |
# | nupdates           | 73            |
# | policy_entropy     | 0.41924977    |
# | policy_loss        | -0.0034991414 |
# | serial_timesteps   | 18688         |
# | time_elapsed       | 5.17e+03      |
# | total_timesteps    | 598016        |
# | value_loss         | 0.0005682461  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.2925734     |
# | clipfrac           | 0.45576173    |
# | eplenmean          | 197           |
# | eprewmean          | -650          |
# | explained_variance | -0.0241       |
# | fps                | 116           |
# | nupdates           | 74            |
# | policy_entropy     | 0.40361413    |
# | policy_loss        | -0.010740976  |
# | serial_timesteps   | 18944         |
# | time_elapsed       | 5.24e+03      |
# | total_timesteps    | 606208        |
# | value_loss         | 0.00062768784 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.29800183    |
# | clipfrac           | 0.45007935    |
# | eplenmean          | 191           |
# | eprewmean          | -667          |
# | explained_variance | -0.00265      |
# | fps                | 115           |
# | nupdates           | 75            |
# | policy_entropy     | 0.40503287    |
# | policy_loss        | -0.010104721  |
# | serial_timesteps   | 19200         |
# | time_elapsed       | 5.31e+03      |
# | total_timesteps    | 614400        |
# | value_loss         | 0.00050793716 |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.2968176    |
# | clipfrac           | 0.45557863   |
# | eplenmean          | 208          |
# | eprewmean          | -781         |
# | explained_variance | -0.00573     |
# | fps                | 115          |
# | nupdates           | 76           |
# | policy_entropy     | 0.40108687   |
# | policy_loss        | -0.007820833 |
# | serial_timesteps   | 19456        |
# | time_elapsed       | 5.38e+03     |
# | total_timesteps    | 622592       |
# | value_loss         | 0.0012526761 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.32608944    |
# | clipfrac           | 0.45882568    |
# | eplenmean          | 197           |
# | eprewmean          | -897          |
# | explained_variance | -0.0033       |
# | fps                | 115           |
# | nupdates           | 77            |
# | policy_entropy     | 0.40177256    |
# | policy_loss        | -0.0034730926 |
# | serial_timesteps   | 19712         |
# | time_elapsed       | 5.45e+03      |
# | total_timesteps    | 630784        |
# | value_loss         | 0.0017005187  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.318962     |
# | clipfrac           | 0.44907227   |
# | eplenmean          | 199          |
# | eprewmean          | -1.03e+03    |
# | explained_variance | -0.0367      |
# | fps                | 107          |
# | nupdates           | 78           |
# | policy_entropy     | 0.3933944    |
# | policy_loss        | -0.007503657 |
# | serial_timesteps   | 19968        |
# | time_elapsed       | 5.53e+03     |
# | total_timesteps    | 638976       |
# | value_loss         | 0.0006972471 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.29583448    |
# | clipfrac           | 0.43690795    |
# | eplenmean          | 207           |
# | eprewmean          | -896          |
# | explained_variance | -0.0224       |
# | fps                | 105           |
# | nupdates           | 79            |
# | policy_entropy     | 0.3946813     |
# | policy_loss        | -0.0063275634 |
# | serial_timesteps   | 20224         |
# | time_elapsed       | 5.61e+03      |
# | total_timesteps    | 647168        |
# | value_loss         | 0.0005192497  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.3121699     |
# | clipfrac           | 0.44523317    |
# | eplenmean          | 205           |
# | eprewmean          | -748          |
# | explained_variance | -0.00739      |
# | fps                | 105           |
# | nupdates           | 80            |
# | policy_entropy     | 0.39417735    |
# | policy_loss        | -0.0075073056 |
# | serial_timesteps   | 20480         |
# | time_elapsed       | 5.68e+03      |
# | total_timesteps    | 655360        |
# | value_loss         | 0.000940382   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.3062611     |
# | clipfrac           | 0.45039064    |
# | eplenmean          | 212           |
# | eprewmean          | -735          |
# | explained_variance | 0.00191       |
# | fps                | 104           |
# | nupdates           | 81            |
# | policy_entropy     | 0.40122277    |
# | policy_loss        | -0.006199735  |
# | serial_timesteps   | 20736         |
# | time_elapsed       | 5.76e+03      |
# | total_timesteps    | 663552        |
# | value_loss         | 0.00087730994 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.31641144    |
# | clipfrac           | 0.4526306     |
# | eplenmean          | 226           |
# | eprewmean          | -882          |
# | explained_variance | -0.000916     |
# | fps                | 105           |
# | nupdates           | 82            |
# | policy_entropy     | 0.40444922    |
# | policy_loss        | -0.0068338225 |
# | serial_timesteps   | 20992         |
# | time_elapsed       | 5.84e+03      |
# | total_timesteps    | 671744        |
# | value_loss         | 0.001337975   |
# --------------------------------------
# ...
# | eplenmean          | 1.62e+03       |
# | eprewmean          | -13            |
# | explained_variance | -0.00246       |
# | fps                | 118            |
# | nupdates           | 746            |
# | policy_entropy     | 0.008550572    |
# | policy_loss        | -0.00018156474 |
# | serial_timesteps   | 190976         |
# | time_elapsed       | 5.24e+04       |
# | total_timesteps    | 6111232        |
# | value_loss         | 1.2219e-05     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 6.155488e-06  |
# | clipfrac           | 0.00057373045 |
# | eplenmean          | 1.62e+03      |
# | eprewmean          | -13.1         |
# | explained_variance | -9.89e-06     |
# | fps                | 119           |
# | nupdates           | 747           |
# | policy_entropy     | 0.009224623   |
# | policy_loss        | -4.318208e-05 |
# | serial_timesteps   | 191232        |
# | time_elapsed       | 5.24e+04      |
# | total_timesteps    | 6119424       |
# | value_loss         | 2.8588136e-06 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.6309898e-06 |
# | clipfrac           | 0.00021972656 |
# | eplenmean          | 1.62e+03      |
# | eprewmean          | -12.7         |
# | explained_variance | -0.00511      |
# | fps                | 120           |
# | nupdates           | 748           |
# | policy_entropy     | 0.008596098   |
# | policy_loss        | 9.836391e-06  |
# | serial_timesteps   | 191488        |
# | time_elapsed       | 5.25e+04      |
# | total_timesteps    | 6127616       |
# | value_loss         | 3.785366e-06  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.029049e-05   |
# | clipfrac           | 0.00065307616  |
# | eplenmean          | 1.62e+03       |
# | eprewmean          | -14.4          |
# | explained_variance | -0.00338       |
# | fps                | 119            |
# | nupdates           | 749            |
# | policy_entropy     | 0.008581841    |
# | policy_loss        | -0.00017031105 |
# | serial_timesteps   | 191744         |
# | time_elapsed       | 5.26e+04       |
# | total_timesteps    | 6135808        |
# | value_loss         | 6.3172542e-06  |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.3946503e-05  |
# | clipfrac           | 0.00083007815  |
# | eplenmean          | 1.62e+03       |
# | eprewmean          | -14.4          |
# | explained_variance | -0.00562       |
# | fps                | 122            |
# | nupdates           | 750            |
# | policy_entropy     | 0.009359649    |
# | policy_loss        | -2.7812372e-05 |
# | serial_timesteps   | 192000         |
# | time_elapsed       | 5.26e+04       |
# | total_timesteps    | 6144000        |
# | value_loss         | 5.4188577e-06  |
# ---------------------------------------
# Saving to /tmp/openai-2018-08-23-09-38-32-256117/checkpoints/00750
# ---------------------------------------
# | approxkl           | 9.166711e-06   |
# | clipfrac           | 0.00070800784  |
# | eplenmean          | 1.62e+03       |
# | eprewmean          | -15.3          |
# | explained_variance | -4.59e-05      |
# | fps                | 122            |
# | nupdates           | 751            |
# | policy_entropy     | 0.008507499    |
# | policy_loss        | -0.00014206898 |
# | serial_timesteps   | 192256         |
# | time_elapsed       | 5.27e+04       |
# | total_timesteps    | 6152192        |
# | value_loss         | 1.007762e-05   |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.2337921e-05  |
# | clipfrac           | 0.00054321287  |
# | eplenmean          | 1.62e+03       |
# | eprewmean          | -15.7          |
# | explained_variance | -2.99e-05      |
# | fps                | 121            |
# | nupdates           | 752            |
# | policy_entropy     | 0.008656578    |
# | policy_loss        | -0.00017542404 |
# | serial_timesteps   | 192512         |
# | time_elapsed       | 5.28e+04       |
# | total_timesteps    | 6160384        |
# | value_loss         | 4.123593e-06   |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.0202471e-05  |
# | clipfrac           | 0.0007019043   |
# | eplenmean          | 1.62e+03       |
# | eprewmean          | -15.7          |
# | explained_variance | -0.00419       |
# | fps                | 122            |
# | nupdates           | 753            |
# | policy_entropy     | 0.00829418     |
# | policy_loss        | -1.3636221e-05 |
# | serial_timesteps   | 192768         |
# | time_elapsed       | 5.28e+04       |
# | total_timesteps    | 6168576        |
# | value_loss         | 1.5558151e-05  |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.2391766e-05 |
# | clipfrac           | 0.0010070801  |
# | eplenmean          | 1.62e+03      |
# | eprewmean          | -16.9         |
# | explained_variance | -1.28e-05     |
# | fps                | 122           |
# | nupdates           | 754           |
# | policy_entropy     | 0.009336707   |
# | policy_loss        | -9.073705e-05 |
# | serial_timesteps   | 193024        |
# | time_elapsed       | 5.29e+04      |
# | total_timesteps    | 6176768       |
# | value_loss         | 3.2467753e-06 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.630042e-06  |
# | clipfrac           | 0.0005859375  |
# | eplenmean          | 1.62e+03      |
# | eprewmean          | -14.3         |
# | explained_variance | -2.38e-07     |
# | fps                | 122           |
# | nupdates           | 755           |
# | policy_entropy     | 0.00986674    |
# | policy_loss        | -8.856023e-05 |
# | serial_timesteps   | 193280        |
# | time_elapsed       | 5.3e+04       |
# | total_timesteps    | 6184960       |
# | value_loss         | 1.2256753e-05 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.4657163e-06 |
# | clipfrac           | 0.0003112793  |
# | eplenmean          | 1.62e+03      |
# | eprewmean          | -15.3         |
# | explained_variance | 0.0136        |
# | fps                | 121           |
# | nupdates           | 756           |
# | policy_entropy     | 0.00875294    |
# | policy_loss        | 9.709544e-06  |
# | serial_timesteps   | 193536        |
# | time_elapsed       | 5.3e+04       |
# | total_timesteps    | 6193152       |
# | value_loss         | 4.369273e-06  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 8.572142e-06   |
# | clipfrac           | 0.0007751465   |
# | eplenmean          | 1.62e+03       |
# | eprewmean          | -15.1          |
# | explained_variance | -3.34e-06      |
# | fps                | 122            |
# | nupdates           | 757            |
# | policy_entropy     | 0.008497999    |
# | policy_loss        | -0.00016240831 |
# | serial_timesteps   | 193792         |
# | time_elapsed       | 5.31e+04       |
# | total_timesteps    | 6201344        |
# | value_loss         | 6.151501e-06   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.0185411e-05 |
# | clipfrac           | 0.0005371094  |
# | eplenmean          | 1.62e+03      |
# | eprewmean          | -14.1         |
# | explained_variance | -2.9e-05      |
# | fps                | 121           |
# | nupdates           | 758           |
# | policy_entropy     | 0.009288562   |
# | policy_loss        | -1.911816e-05 |
# | serial_timesteps   | 194048        |
# | time_elapsed       | 5.32e+04      |
# | total_timesteps    | 6209536       |
# | value_loss         | 5.577839e-06  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.2943774e-05 |
# | clipfrac           | 0.0011047364  |
# | eplenmean          | 1.62e+03      |
# | eprewmean          | -14.8         |
# | explained_variance | 0.00638       |
# | fps                | 122           |
# | nupdates           | 759           |
# | policy_entropy     | 0.009702372   |
# | policy_loss        | -7.633456e-05 |
# | serial_timesteps   | 194304        |
# | time_elapsed       | 5.33e+04      |
# | total_timesteps    | 6217728       |
# | value_loss         | 2.0250753e-05 |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 7.779485e-06   |
# | clipfrac           | 0.0006469727   |
# | eplenmean          | 1.62e+03       |
# | eprewmean          | -14.3          |
# | explained_variance | -0.0111        |
# | fps                | 119            |
# | nupdates           | 760            |
# | policy_entropy     | 0.009740356    |
# | policy_loss        | -0.00010185887 |
# | serial_timesteps   | 194560         |
# | time_elapsed       | 5.33e+04       |
# | total_timesteps    | 6225920        |
# | value_loss         | 7.213199e-06   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 4.244855e-06  |
# | clipfrac           | 0.00029907227 |
# | eplenmean          | 1.62e+03      |
# | eprewmean          | -14.7         |
# | explained_variance | -0.00395      |
# | fps                | 119           |
# | nupdates           | 761           |
# | policy_entropy     | 0.009028526   |
# | policy_loss        | -6.288527e-05 |
# | serial_timesteps   | 194816        |
# | time_elapsed       | 5.34e+04      |
# | total_timesteps    | 6234112       |
# | value_loss         | 5.337232e-06  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.7257717e-05  |
# | clipfrac           | 0.00079956057  |
# | eplenmean          | 1.62e+03       |
# | eprewmean          | -11.1          |
# | explained_variance | 1.45e-05       |
# | fps                | 120            |
# | nupdates           | 762            |
# | policy_entropy     | 0.007675118    |
# | policy_loss        | -0.00025109595 |
# | serial_timesteps   | 195072         |
# | time_elapsed       | 5.35e+04       |
# | total_timesteps    | 6242304        |
# | value_loss         | 7.536998e-06   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.0925867e-05 |
# | clipfrac           | 0.00065307616 |
# | eplenmean          | 1.62e+03      |
# | eprewmean          | -11.7         |
# | explained_variance | 2.98e-07      |
# | fps                | 121           |
# | nupdates           | 763           |
# | policy_entropy     | 0.006888613   |
# | policy_loss        | -6.963252e-05 |
# | serial_timesteps   | 195328        |
# | time_elapsed       | 5.35e+04      |
# | total_timesteps    | 6250496       |
# | value_loss         | 7.676652e-06  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.4944778e-06  |
# | clipfrac           | 0.00010375977  |
# | eplenmean          | 1.62e+03       |
# | eprewmean          | -10.7          |
# | explained_variance | -6.6e-05       |
# | fps                | 120            |
# | nupdates           | 764            |
# | policy_entropy     | 0.0065696174   |
# | policy_loss        | -5.5775017e-05 |
# | serial_timesteps   | 195584         |
# | time_elapsed       | 5.36e+04       |
# | total_timesteps    | 6258688        |
# | value_loss         | 2.420828e-06   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.1911214e-06 |
# | clipfrac           | 0.00010986328 |
# | eplenmean          | 1.62e+03      |
# | eprewmean          | -10.7         |
# | explained_variance | -4.57e-05     |
# | fps                | 120           |
# | nupdates           | 765           |
# | policy_entropy     | 0.0058199703  |
# | policy_loss        | -7.080556e-05 |
# | serial_timesteps   | 195840        |
# | time_elapsed       | 5.37e+04      |
# | total_timesteps    | 6266880       |
# | value_loss         | 1.617768e-06  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.1891377e-06  |
# | clipfrac           | 0.00010375977  |
# | eplenmean          | 1.62e+03       |
# | eprewmean          | -10.7          |
# | explained_variance | -0.000986      |
# | fps                | 121            |
# | nupdates           | 766            |
# | policy_entropy     | 0.0068447394   |
# | policy_loss        | -4.4290673e-06 |
# | serial_timesteps   | 196096         |
# | time_elapsed       | 5.37e+04       |
# | total_timesteps    | 6275072        |
# | value_loss         | 6.403347e-08   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.3641164e-06 |
# | clipfrac           | 0.00016479492 |
# | eplenmean          | 1.62e+03      |
# | eprewmean          | -11           |
# | explained_variance | -6.56e-06     |
# | fps                | 118           |
# | nupdates           | 767           |
# | policy_entropy     | 0.007611307   |
# | policy_loss        | 4.1730797e-05 |
# | serial_timesteps   | 196352        |
# | time_elapsed       | 5.38e+04      |
# | total_timesteps    | 6283264       |
# | value_loss         | 4.275675e-06  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.0898544e-05  |
# | clipfrac           | 0.00068359374  |
# | eplenmean          | 1.62e+03       |
# | eprewmean          | -13.3          |
# | explained_variance | 0.00138        |
# | fps                | 117            |
# | nupdates           | 768            |
# | policy_entropy     | 0.008136765    |
# | policy_loss        | -6.3764615e-05 |
# | serial_timesteps   | 196608         |
# | time_elapsed       | 5.39e+04       |
# | total_timesteps    | 6291456        |
# | value_loss         | 9.151221e-06   |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.3328623e-05  |
# | clipfrac           | 0.00091552734  |
# | eplenmean          | 1.62e+03       |
# | eprewmean          | -13.3          |
# | explained_variance | -0.0207        |
# | fps                | 114            |
# | nupdates           | 769            |
# | policy_entropy     | 0.008185403    |
# | policy_loss        | -3.0218367e-05 |
# | serial_timesteps   | 196864         |
# | time_elapsed       | 5.39e+04       |
# | total_timesteps    | 6299648        |
# | value_loss         | 1.5678965e-05  |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 8.092055e-06   |
# | clipfrac           | 0.0008666992   |
# | eplenmean          | 1.62e+03       |
# | eprewmean          | -12.7          |
# | explained_variance | -7.37e-05      |
# | fps                | 112            |
# | nupdates           | 770            |
# | policy_entropy     | 0.007420442    |
# | policy_loss        | -0.00018280227 |
# | serial_timesteps   | 197120         |
# | time_elapsed       | 5.4e+04        |
# | total_timesteps    | 6307840        |
# | value_loss         | 4.4261856e-06  |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 6.1073233e-06 |
# | clipfrac           | 0.00056762696 |
# | eplenmean          | 1.62e+03      |
# | eprewmean          | -12.2         |
# | explained_variance | -3.58e-07     |
# | fps                | 112           |
# | nupdates           | 771           |
# | policy_entropy     | 0.00805726    |
# | policy_loss        | -9.491964e-05 |
# | serial_timesteps   | 197376        |
# | time_elapsed       | 5.41e+04      |
# | total_timesteps    | 6316032       |
# | value_loss         | 1.5814588e-06 |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.2067277e-05  |
# | clipfrac           | 0.0010925293   |
# | eplenmean          | 1.62e+03       |
# | eprewmean          | -12.7          |
# | explained_variance | -0.00106       |
# | fps                | 112            |
# | nupdates           | 772            |
# | policy_entropy     | 0.0067348974   |
# | policy_loss        | -0.00029747255 |
# | serial_timesteps   | 197632         |
# | time_elapsed       | 5.42e+04       |
# | total_timesteps    | 6324224        |
# | value_loss         | 1.07481665e-05 |
# ---------------------------------------

# %%
load_path = '/tmp/openai-2018-05-29-15-08-04-310254/checkpoints/00100'
logger.get_dir()
# Out:
# '/tmp/openai-2018-05-29-15-08-04-310254'

# %%
def test(env_id, load_path, seed):

    ncpu = multiprocessing.cpu_count()
    if sys.platform == 'darwin': ncpu //= 2
    config = tf.ConfigProto(allow_soft_placement=True,
                            intra_op_parallelism_threads=ncpu,
                            inter_op_parallelism_threads=ncpu)
    config.gpu_options.allow_growth = True #pylint: disable=E1101
    tf.Session(config=config).__enter__()
    
    def make_env():
        env = gym.make(env_id)
        return env
    
    
    env = DummyVecEnv([make_env])
    running_mean = np.load('{}/mean.npy'.format(load_path))
    running_var = np.load('{}/var.npy'.format(load_path))
    env = VecNormalizeTest(env, running_mean, running_var)
    set_global_seeds(seed)

    policy = LstmPolicy
    ob_space = env.venv.observation_space
    ac_space = env.venv.action_space
    nbatch_act = 1 * 1
    nbatch_train = 32 * 8
    nsteps = 256
    ent_coef = .01
    vf_coef = 0.5
    max_grad_norm = 0.5
    make_model = lambda : ppo2.Model(policy=policy, ob_space=ob_space, ac_space=ac_space, 
                                nbatch_act=nbatch_act, nbatch_train=nbatch_train, nsteps=nsteps, 
                                ent_coef=ent_coef, vf_coef=vf_coef, max_grad_norm=max_grad_norm)
    model = make_model()
    model.load(load_path + '/checkpoints/01200')
    
    obs = env.reset()
    states = model.initial_state
    dones = [False for _ in range(1)]
    while True:
        actions, _, states, _, = model.step(obs, states, dones)
        obs[:], _, dones, _, = env.step(actions)
        env.venv.render()

# %%
load_path = '../data/processed'
load_path = '/tmp/openai-2018-06-22-12-45-22-090687'
test('tradingenv-v0', load_path, seed=0)
# Out:
# WARNING:tensorflow:From /home/ubuntu/repos/baselines/baselines/common/distributions.py:148: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# WARNING:tensorflow:From /home/ubuntu/repos/baselines/baselines/common/distributions.py:159: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/ubuntu/repos/baselines/baselines/common/distributions.py:161: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
def make_env():
        env = gym.make('tradingenv-v0')
        return env
env = DummyVecEnv([make_env])
load_path = '/tmp/openai-2018-05-29-15-08-04-310254'
running_mean = np.load('{}/mean.npy'.format(load_path))
running_var = np.load('{}/var.npy'.format(load_path))
env = VecNormalizeTest(env, running_mean, running_var)

# %%
import gym
e = gym.make('tradingenv-v5')

# %%
e.step(1)
# Out:
# (array([[ 2.44675000e+03,  2.44800000e+03,  2.44675000e+03,
#           2.44725000e+03, -8.43391446e-01, -5.37299608e-01,
#           0.00000000e+00],
#         [ 2.44725000e+03,  2.44800000e+03,  2.44675000e+03,
#           2.44700000e+03, -8.54911871e-01, -5.18773258e-01,
#           0.00000000e+00],
#         [ 2.44700000e+03,  2.44775000e+03,  2.44675000e+03,
#           2.44700000e+03, -8.66025404e-01, -5.00000000e-01,
#           0.00000000e+00],
#         [ 2.44725000e+03,  2.44875000e+03,  2.44700000e+03,
#           2.44775000e+03, -8.76726756e-01, -4.80988769e-01,
#           0.00000000e+00],
#         [ 2.44800000e+03,  2.44925000e+03,  2.44775000e+03,
#           2.44850000e+03, -8.87010833e-01, -4.61748613e-01,
#           0.00000000e+00],
#         [ 2.44850000e+03,  2.44950000e+03,  2.44850000e+03,
#           2.44900000e+03, -8.96872742e-01, -4.42288690e-01,
#           0.00000000e+00],
#         [ 2.44900000e+03,  2.44950000e+03,  2.44850000e+03,
#           2.44850000e+03, -9.06307787e-01, -4.22618262e-01,
#           0.00000000e+00],
#         [ 2.44875000e+03,  2.44875000e+03,  2.44775000e+03,
#           2.44800000e+03, -9.15311479e-01, -4.02746690e-01,
#           0.00000000e+00],
#         [ 2.44800000e+03,  2.44825000e+03,  2.44725000e+03,
#           2.44775000e+03, -9.23879533e-01, -3.82683432e-01,
#           0.00000000e+00],
#         [ 2.44775000e+03,  2.44800000e+03,  2.44725000e+03,
#           2.44750000e+03, -9.32007869e-01, -3.62438038e-01,
#           0.00000000e+00],
#         [ 2.44750000e+03,  2.44775000e+03,  2.44675000e+03,
#           2.44675000e+03, -9.39692621e-01, -3.42020143e-01,
#           0.00000000e+00],
#         [ 2.44675000e+03,  2.44750000e+03,  2.44675000e+03,
#           2.44725000e+03, -9.46930129e-01, -3.21439465e-01,
#           0.00000000e+00],
#         [ 2.44750000e+03,  2.44775000e+03,  2.44675000e+03,
#           2.44750000e+03, -9.53716951e-01, -3.00705800e-01,
#           0.00000000e+00],
#         [ 2.44750000e+03,  2.44800000e+03,  2.44725000e+03,
#           2.44725000e+03, -9.60049854e-01, -2.79829014e-01,
#           0.00000000e+00],
#         [ 2.44725000e+03,  2.44850000e+03,  2.44725000e+03,
#           2.44800000e+03, -9.65925826e-01, -2.58819045e-01,
#           0.00000000e+00],
#         [ 2.44825000e+03,  2.44950000e+03,  2.44800000e+03,
#           2.44925000e+03, -9.71342070e-01, -2.37685892e-01,
#           0.00000000e+00],
#         [ 2.44925000e+03,  2.44925000e+03,  2.44825000e+03,
#           2.44850000e+03, -9.76296007e-01, -2.16439614e-01,
#           0.00000000e+00],
#         [ 2.44875000e+03,  2.44925000e+03,  2.44850000e+03,
#           2.44900000e+03, -9.80785280e-01, -1.95090322e-01,
#           0.00000000e+00],
#         [ 2.44925000e+03,  2.44925000e+03,  2.44800000e+03,
#           2.44850000e+03, -9.84807753e-01, -1.73648178e-01,
#           0.00000000e+00],
#         [ 2.44825000e+03,  2.44900000e+03,  2.44825000e+03,
#           2.44825000e+03, -9.88361510e-01, -1.52123386e-01,
#           0.00000000e+00],
#         [ 2.44850000e+03,  2.44900000e+03,  2.44825000e+03,
#           2.44900000e+03, -9.91444861e-01, -1.30526192e-01,
#           0.00000000e+00],
#         [ 2.44900000e+03,  2.44900000e+03,  2.44850000e+03,
#           2.44875000e+03, -9.94056338e-01, -1.08866875e-01,
#           0.00000000e+00],
#         [ 2.44850000e+03,  2.44950000e+03,  2.44850000e+03,
#           2.44875000e+03, -9.96194698e-01, -8.71557427e-02,
#           0.00000000e+00],
#         [ 2.44875000e+03,  2.44925000e+03,  2.44800000e+03,
#           2.44800000e+03, -9.97858923e-01, -6.54031292e-02,
#           0.00000000e+00],
#         [ 2.44800000e+03,  2.44850000e+03,  2.44800000e+03,
#           2.44850000e+03, -9.99048222e-01, -4.36193874e-02,
#           0.00000000e+00],
#         [ 2.44850000e+03,  2.44875000e+03,  2.44800000e+03,
#           2.44800000e+03, -9.99762027e-01, -2.18148850e-02,
#           0.00000000e+00],
#         [ 2.44800000e+03,  2.44825000e+03,  2.44750000e+03,
#           2.44800000e+03, -1.00000000e+00, -1.83697020e-16,
#           0.00000000e+00],
#         [ 2.44825000e+03,  2.44875000e+03,  2.44800000e+03,
#           2.44800000e+03, -9.99762027e-01,  2.18148850e-02,
#           0.00000000e+00],
#         [ 2.44800000e+03,  2.44825000e+03,  2.44750000e+03,
#           2.44800000e+03, -9.99048222e-01,  4.36193874e-02,
#           0.00000000e+00],
#         [ 2.44800000e+03,  2.44825000e+03,  2.44750000e+03,
#           2.44800000e+03, -9.97858923e-01,  6.54031292e-02,
#           0.00000000e+00],
#         [ 2.44800000e+03,  2.45000000e+03,  2.44775000e+03,
#           2.45000000e+03, -9.96194698e-01,  8.71557427e-02,
#           0.00000000e+00],
#         [ 2.45000000e+03,  2.45075000e+03,  2.44975000e+03,
#           2.45025000e+03, -9.94056338e-01,  1.08866875e-01,
#           0.00000000e+00],
#         [ 2.45050000e+03,  2.45150000e+03,  2.45000000e+03,
#           2.45100000e+03, -9.91444861e-01,  1.30526192e-01,
#           0.00000000e+00],
#         [ 2.45100000e+03,  2.45250000e+03,  2.45100000e+03,
#           2.45200000e+03, -9.88361510e-01,  1.52123386e-01,
#           0.00000000e+00],
#         [ 2.45225000e+03,  2.45250000e+03,  2.45175000e+03,
#           2.45200000e+03, -9.84807753e-01,  1.73648178e-01,
#           0.00000000e+00],
#         [ 2.45200000e+03,  2.45250000e+03,  2.45100000e+03,
#           2.45175000e+03, -9.80785280e-01,  1.95090322e-01,
#           0.00000000e+00],
#         [ 2.45175000e+03,  2.45200000e+03,  2.45075000e+03,
#           2.45100000e+03, -9.76296007e-01,  2.16439614e-01,
#           0.00000000e+00],
#         [ 2.45100000e+03,  2.45175000e+03,  2.45050000e+03,
#           2.45150000e+03, -9.71342070e-01,  2.37685892e-01,
#           0.00000000e+00],
#         [ 2.45175000e+03,  2.45200000e+03,  2.45100000e+03,
#           2.45175000e+03, -9.65925826e-01,  2.58819045e-01,
#           0.00000000e+00],
#         [ 2.45150000e+03,  2.45200000e+03,  2.45100000e+03,
#           2.45175000e+03, -9.60049854e-01,  2.79829014e-01,
#           0.00000000e+00],
#         [ 2.45150000e+03,  2.45200000e+03,  2.45100000e+03,
#           2.45200000e+03, -9.53716951e-01,  3.00705800e-01,
#           0.00000000e+00],
#         [ 2.45200000e+03,  2.45275000e+03,  2.45175000e+03,
#           2.45225000e+03, -9.46930129e-01,  3.21439465e-01,
#           0.00000000e+00],
#         [ 2.45250000e+03,  2.45300000e+03,  2.45200000e+03,
#           2.45225000e+03, -9.39692621e-01,  3.42020143e-01,
#           0.00000000e+00],
#         [ 2.45250000e+03,  2.45300000e+03,  2.45175000e+03,
#           2.45175000e+03, -9.32007869e-01,  3.62438038e-01,
#           0.00000000e+00],
#         [ 2.45175000e+03,  2.45250000e+03,  2.45150000e+03,
#           2.45200000e+03, -9.23879533e-01,  3.82683432e-01,
#           0.00000000e+00],
#         [ 2.45200000e+03,  2.45275000e+03,  2.45175000e+03,
#           2.45175000e+03, -9.15311479e-01,  4.02746690e-01,
#           0.00000000e+00],
#         [ 2.45175000e+03,  2.45300000e+03,  2.45175000e+03,
#           2.45225000e+03, -9.06307787e-01,  4.22618262e-01,
#           0.00000000e+00],
#         [ 2.45225000e+03,  2.45400000e+03,  2.45200000e+03,
#           2.45350000e+03, -8.96872742e-01,  4.42288690e-01,
#           0.00000000e+00],
#         [ 2.45350000e+03,  2.45500000e+03,  2.45325000e+03,
#           2.45425000e+03, -8.87010833e-01,  4.61748613e-01,
#           0.00000000e+00],
#         [ 2.45400000e+03,  2.45450000e+03,  2.45275000e+03,
#           2.45350000e+03, -8.76726756e-01,  4.80988769e-01,
#           0.00000000e+00],
#         [ 2.45325000e+03,  2.45375000e+03,  2.45125000e+03,
#           2.45225000e+03, -8.66025404e-01,  5.00000000e-01,
#           0.00000000e+00],
#         [ 2.45225000e+03,  2.45275000e+03,  2.45100000e+03,
#           2.45200000e+03, -8.54911871e-01,  5.18773258e-01,
#           0.00000000e+00],
#         [ 2.45200000e+03,  2.45200000e+03,  2.45100000e+03,
#           2.45125000e+03, -8.43391446e-01,  5.37299608e-01,
#           0.00000000e+00],
#         [ 2.45100000e+03,  2.45425000e+03,  2.45100000e+03,
#           2.45425000e+03, -8.31469612e-01,  5.55570233e-01,
#           0.00000000e+00],
#         [ 2.44150000e+03,  2.44400000e+03,  2.43975000e+03,
#           2.44200000e+03, -4.02746690e-01, -9.15311479e-01,
#           0.00000000e+00],
#         [ 2.44225000e+03,  2.44500000e+03,  2.44150000e+03,
#           2.44475000e+03, -4.22618262e-01, -9.06307787e-01,
#           0.00000000e+00],
#         [ 2.44475000e+03,  2.44500000e+03,  2.44250000e+03,
#           2.44350000e+03, -4.42288690e-01, -8.96872742e-01,
#           0.00000000e+00],
#         [ 2.44350000e+03,  2.44575000e+03,  2.44325000e+03,
#           2.44500000e+03, -4.61748613e-01, -8.87010833e-01,
#           0.00000000e+00],
#         [ 2.44500000e+03,  2.44575000e+03,  2.44350000e+03,
#           2.44525000e+03, -4.80988769e-01, -8.76726756e-01,
#           0.00000000e+00],
#         [ 2.44525000e+03,  2.44675000e+03,  2.44500000e+03,
#           2.44625000e+03, -5.00000000e-01, -8.66025404e-01,
#           0.00000000e+00],
#         [ 2.44600000e+03,  2.44600000e+03,  2.44400000e+03,
#           2.44500000e+03, -5.18773258e-01, -8.54911871e-01,
#           0.00000000e+00],
#         [ 2.44500000e+03,  2.44625000e+03,  2.44225000e+03,
#           2.44300000e+03, -5.37299608e-01, -8.43391446e-01,
#           0.00000000e+00],
#         [ 2.44300000e+03,  2.44525000e+03,  2.44275000e+03,
#           2.44450000e+03, -5.55570233e-01, -8.31469612e-01,
#           0.00000000e+00],
#         [ 2.44475000e+03,  2.44725000e+03,  2.44450000e+03,
#           2.44625000e+03, -5.73576436e-01, -8.19152044e-01,
#           0.00000000e+00]]), 0, False, {})
